# %% [markdown]
# # char-RNNs for baby name learning
#
# So the motivation behind this is learning more about character-level RNNs and implementing my first for the purpose of randomly generating names for my amusement (sad I know ...). Inspiration is drawn from [Andrej Karpathy's excellent blog post](http://karpathy.github.io/2015/05/21/rnn-effectiveness/).

# %%
import numpy as np
import tensorflow as tf
from tensorflow.contrib import rnn
import pandas as pd
from __future__ import division 
import matplotlib.pyplot as plt
plt.style.use("fivethirtyeight")
# %matplotlib inline

# %% [markdown]
# # A minimal character-level Vanilla RNN model with fixed input length

# %%
# read the data
baby_names = pd.read_csv("data/NationalNames.csv")
baby_names.head()
# Out:
#    Id       Name  Year Gender  Count
# 0   1       Mary  1880      F   7065
# 1   2       Anna  1880      F   2604
# 2   3       Emma  1880      F   2003
# 3   4  Elizabeth  1880      F   1939
# 4   5     Minnie  1880      F   1746

# %%
# let's just keep the names for now
names = baby_names.Name.values
length_five = names[np.array([len(n) for n in names])==5]
chars = "".join(length_five) # gonna keep uppercase, lowercase for now
vocab = set(list(chars))
vocab_size = len(vocab)

print("Number of characters: {}".format(len(chars)))
print("Number of unique characters: {}".format(vocab_size)) # As many as English alphabet both upper and lowercase
# Out:
# Number of characters: 1912720
# Number of unique characters: 52

# %%
# make a mapping from indices to characters and back
dictionary = dict(enumerate(vocab))
reverse_dictionary = {value:key for key, value in dictionary.iteritems()}

# %%
# some hyperparameters
hidden_size = 100 # size of the hidden state of the RNN  
seq_length = 5 # number of steps to unroll RNN
lr = 1e-2

# %%
# Define placeholders
inputs = tf.placeholder(tf.float32, [None, vocab_size], name='inputs') # ohe representation of the character
targets = tf.placeholder(tf.float32, [None, vocab_size], name='outputs') # ohe representation of the character
init_state = tf.placeholder(shape=[1, hidden_size], dtype=tf.float32, name='input_state')

# %%
# Define some variables
Whh = tf.Variable(tf.truncated_normal([hidden_size, hidden_size], stddev=0.01))
Wxh = tf.Variable(tf.truncated_normal([vocab_size, hidden_size], stddev=0.01))
Why = tf.Variable(tf.truncated_normal([hidden_size, vocab_size], stddev=0.01))
bh = tf.Variable(tf.constant(0.1, dtype=tf.float32, shape=(1, hidden_size)))
by = tf.Variable(tf.constant(0.1, dtype=tf.float32, shape=(1, vocab_size)))

# %%
# Feed input and update hidden state
# We pass one name of length 5 at a time

preds = []
hidden_state = init_state
for t, x_t in enumerate(tf.split(inputs, seq_length, 0)):
    # update hidden state
    hidden_state = tf.tanh(tf.matmul(x_t, Wxh) + tf.matmul(hidden_state, Whh) + bh)
    
    # update the output, only the last thing will predict something
    output = tf.matmul(hidden_state, Why) + by
    preds.append(output)  

preds = preds[:-1]
outputs = tf.concat(preds, axis=0)

# %%
# Setup the loss

# your regular cross-entropy as the loss
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=targets, logits=outputs))

# Adam for starters
train_step = tf.train.AdamOptimizer().minimize(loss)

# %%
def word2mat(w):
    "Given a name, it returns a <name length> by <vocab size> matrix"
    mat = np.zeros([len(w), vocab_size])
    
    for ix in range(len(w)):
        char = w[ix]
        char_id = reverse_dictionary[char]
        mat[ix, char_id] = 1
    return mat

def mat2word(mat):
    return "".join([dictionary[ix] for ix in np.argmax(mat, 1)])

# %%
# train the network
sess = tf.Session()
init = tf.global_variables_initializer()
sess.run([init])

l = []

n_iter = len(length_five)
h_last = np.zeros([1, hidden_size])
n_epochs = 20

for e in range(n_epochs):
    # shuffle training set in between epochs
    #length_five = np.random.permutation(length_five)
    for ix in range(n_iter):
        w = length_five[ix]
        mat = word2mat(w)
        _, l_new, h_last = sess.run([train_step, loss, hidden_state], feed_dict={inputs:mat, targets:mat[1:, :],
                                                                               init_state:h_last})
        l.append(l_new)

        if ix%10000==0:
            print("Step:{} - Loss: {}".format(ix, np.mean(l[:-10000]))) # track the mean loss to see if we are learning anything
            # generate 10 names and print them
    #         names = [generate_random_name() for _ in range(5)]
    #         print("Names generated: {}".format(" ".join(names)))
            out_ = sess.run(outputs, feed_dict={inputs:mat, targets:mat[1:, :], init_state:h_last})
            print("Wanted to predict: ", mat2word(mat[:, :]))
            print("Got: ", mat2word(mat[:, :])[0]+mat2word(out_))
            print("In dataset: {}".format(mat2word(mat[:, :])[0]+mat2word(out_) in length_five))
# Out:
# Step:0 - Loss: nan
# ('Wanted to predict: ', 'Alice')
# ('Got: ', 'Aiiii')
# In dataset: False
# Step:10000 - Loss: 3.94866299629
# ('Wanted to predict: ', 'Fritz')
# ('Got: ', 'Frach')
# In dataset: False
# Step:20000 - Loss: 2.14521241188
# ('Wanted to predict: ', 'Lexie')
# ('Got: ', 'Looie')
# In dataset: False
# Step:30000 - Loss: 1.98657679558
# ('Wanted to predict: ', 'Alter')
# ('Got: ', 'Aldon')
# In dataset: True
# Step:40000 - Loss: 1.94798660278
# ('Wanted to predict: ', 'Claud')
# ('Got: ', 'Caard')
# In dataset: False
# Step:50000 - Loss: 1.93534576893
# ('Wanted to predict: ', 'Benno')
# ('Got: ', 'Berny')
# In dataset: True
# Step:60000 - Loss: 1.92206263542
# ('Wanted to predict: ', 'Dawne')
# ('Got: ', 'Daria')
# In dataset: True
# Step:70000 - Loss: 1.90611064434
# ('Wanted to predict: ', 'Norva')
# ('Got: ', 'Nenia')
# In dataset: True
# Step:80000 - Loss: 1.88536524773
# ('Wanted to predict: ', 'Toula')
# ('Got: ', 'Tesia')
# In dataset: True
# Step:90000 - Loss: 1.86433625221
# ('Wanted to predict: ', 'Enoch')
# ('Got: ', 'Evnrk')
# In dataset: False
# Step:100000 - Loss: 1.84587323666
# ('Wanted to predict: ', 'Ariel')
# ('Got: ', 'Arlse')
# In dataset: False
# Step:110000 - Loss: 1.83051359653
# ('Wanted to predict: ', 'Linzy')
# ('Got: ', 'Landy')
# In dataset: True
# Step:120000 - Loss: 1.82005560398
# ('Wanted to predict: ', 'Devan')
# ('Got: ', 'Daaon')
# In dataset: False
# Step:130000 - Loss: 1.81254136562
# ('Wanted to predict: ', 'Sarah')
# ('Got: ', 'Sanrh')
# In dataset: False
# Step:140000 - Loss: 1.80761253834
# ('Wanted to predict: ', 'Jacob')
# ('Got: ', 'Jemcb')
# In dataset: False
# Step:150000 - Loss: 1.80379021168
# ('Wanted to predict: ', 'Larri')
# ('Got: ', 'Liiey')
# In dataset: False
# Step:160000 - Loss: 1.801019907
# ('Wanted to predict: ', 'Arlie')
# ('Got: ', 'Alten')
# In dataset: True
# Step:170000 - Loss: 1.80295538902
# ('Wanted to predict: ', 'Johny')
# ('Got: ', 'Jasan')
# In dataset: True
# Step:180000 - Loss: 1.80717885494
# ('Wanted to predict: ', 'Smita')
# ('Got: ', 'Saira')
# In dataset: True
# Step:190000 - Loss: 1.81295335293
# ('Wanted to predict: ', 'Heidy')
# ('Got: ', 'Halda')
# In dataset: False
# Step:200000 - Loss: 1.818177104
# ('Wanted to predict: ', 'Torin')
# ('Got: ', 'Torin')
# In dataset: True
# Step:210000 - Loss: 1.82272994518
# ('Wanted to predict: ', 'Erynn')
# ('Got: ', 'Elina')
# In dataset: True
# Step:220000 - Loss: 1.82685279846
# ('Wanted to predict: ', 'Jovon')
# ('Got: ', 'Jonen')
# In dataset: False
# Step:230000 - Loss: 1.83129739761
# ('Wanted to predict: ', 'Dione')
# ('Got: ', 'Doane')
# In dataset: True
# Step:240000 - Loss: 1.83598875999
# ('Wanted to predict: ', 'Danan')
# ('Got: ', 'Daren')
# In dataset: True
# Step:250000 - Loss: 1.84107244015
# ('Wanted to predict: ', 'Rendy')
# ('Got: ', 'Roney')
# In dataset: True
# Step:260000 - Loss: 1.84608125687
# ('Wanted to predict: ', 'Brayn')
# ('Got: ', 'Bredn')
# In dataset: False
# Step:270000 - Loss: 1.85083699226
# ('Wanted to predict: ', 'Aries')
# ('Got: ', 'Aliol')
# In dataset: False
# Step:280000 - Loss: 1.85610198975
# ('Wanted to predict: ', 'Kyona')
# ('Got: ', 'Kelna')
# In dataset: False
# Step:290000 - Loss: 1.8611549139
# ('Wanted to predict: ', 'Eldar')
# ('Got: ', 'Elien')
# In dataset: False
# Step:300000 - Loss: 1.86732888222
# ('Wanted to predict: ', 'Jaron')
# ('Got: ', 'Jaiin')
# In dataset: False
# Step:310000 - Loss: 1.87201726437
# ('Wanted to predict: ', 'Ryaan')
# ('Got: ', 'Ralnn')
# In dataset: False
# Step:320000 - Loss: 1.87755966187
# ('Wanted to predict: ', 'Casia')
# ('Got: ', 'Calla')
# In dataset: True
# Step:330000 - Loss: 1.88200306892
# ('Wanted to predict: ', 'Axcel')
# ('Got: ', 'Arten')
# In dataset: False
# Step:340000 - Loss: 1.88691496849
# ('Wanted to predict: ', 'Emmah')
# ('Got: ', 'Eliil')
# In dataset: False
# Step:350000 - Loss: 1.89217066765
# ('Wanted to predict: ', 'Aliva')
# ('Got: ', 'Amina')
# In dataset: True
# Step:360000 - Loss: 1.89646708965
# ('Wanted to predict: ', 'Jyden')
# ('Got: ', 'Jaren')
# In dataset: True
# Step:370000 - Loss: 1.90099561214
# ('Wanted to predict: ', 'Rubee')
# ('Got: ', 'Rodiy')
# In dataset: False
# Step:380000 - Loss: 1.90512394905
# ('Wanted to predict: ', 'Kalan')
# ('Got: ', 'Kamen')
# In dataset: True
# Step:0 - Loss: 1.90622878075
# ('Wanted to predict: ', 'Alice')
# ('Got: ', 'Amlae')
# In dataset: False
# Step:10000 - Loss: 1.91123318672
# ('Wanted to predict: ', 'Fritz')
# ('Got: ', 'Flett')
# In dataset: False
# Step:20000 - Loss: 1.9015750885
# ('Wanted to predict: ', 'Lexie')
# ('Got: ', 'Looie')
# In dataset: False
# Step:30000 - Loss: 1.88960087299
# ('Wanted to predict: ', 'Alter')
# ('Got: ', 'Alvon')
# In dataset: True
# Step:40000 - Loss: 1.88299441338
# ('Wanted to predict: ', 'Claud')
# ('Got: ', 'Caerd')
# In dataset: False
# Step:50000 - Loss: 1.87906467915
# ('Wanted to predict: ', 'Benno')
# ('Got: ', 'Burny')
# In dataset: False
# Step:60000 - Loss: 1.87490320206
# ('Wanted to predict: ', 'Dawne')
# ('Got: ', 'Dorna')
# In dataset: True
# Step:70000 - Loss: 1.87006247044
# ('Wanted to predict: ', 'Norva')
# ('Got: ', 'Nelma')
# In dataset: True
# Step:80000 - Loss: 1.86398291588
# ('Wanted to predict: ', 'Toula')
# ('Got: ', 'Trnda')
# In dataset: False
# Step:90000 - Loss: 1.85751914978
# ('Wanted to predict: ', 'Enoch')
# ('Got: ', 'Ednlh')
# In dataset: False
# Step:100000 - Loss: 1.85096144676
# ('Wanted to predict: ', 'Ariel')
# ('Got: ', 'Ariel')
# In dataset: True
# Step:110000 - Loss: 1.84493911266
# ('Wanted to predict: ', 'Linzy')
# ('Got: ', 'Londy')
# In dataset: False
# Step:120000 - Loss: 1.83988189697
# ('Wanted to predict: ', 'Devan')
# ('Got: ', 'Deaon')
# In dataset: False
# Step:130000 - Loss: 1.83553481102
# ('Wanted to predict: ', 'Sarah')
# ('Got: ', 'Sanah')
# In dataset: True
# Step:140000 - Loss: 1.83173918724
# ('Wanted to predict: ', 'Jacob')
# ('Got: ', 'Jameb')
# In dataset: False
# Step:150000 - Loss: 1.82830154896
# ('Wanted to predict: ', 'Larri')
# ('Got: ', 'Lerry')
# In dataset: True
# Step:160000 - Loss: 1.82507026196
# ('Wanted to predict: ', 'Arlie')
# ('Got: ', 'Antee')
# In dataset: False
# Step:170000 - Loss: 1.82342171669
# ('Wanted to predict: ', 'Johny')
# ('Got: ', 'Jasae')
# In dataset: False
# Step:180000 - Loss: 1.82279467583
# ('Wanted to predict: ', 'Smita')
# ('Got: ', 'Seita')
# In dataset: False
# Step:190000 - Loss: 1.82298803329
# ('Wanted to predict: ', 'Heidy')
# ('Got: ', 'Haidi')
# In dataset: True
# Step:200000 - Loss: 1.82315421104
# ('Wanted to predict: ', 'Torin')
# ('Got: ', 'Trris')
# In dataset: False
# Step:210000 - Loss: 1.8233833313
# ('Wanted to predict: ', 'Erynn')
# ('Got: ', 'Elina')
# In dataset: True
# Step:220000 - Loss: 1.82355058193
# ('Wanted to predict: ', 'Jovon')
# ('Got: ', 'Janan')
# In dataset: True
# Step:230000 - Loss: 1.82400095463
# ('Wanted to predict: ', 'Dione')
# ('Got: ', 'Daang')
# In dataset: False
# Step:240000 - Loss: 1.82473468781
# ('Wanted to predict: ', 'Danan')
# ('Got: ', 'Daren')
# In dataset: True
# Step:250000 - Loss: 1.82584667206
# ('Wanted to predict: ', 'Rendy')
# ('Got: ', 'Roeey')
# In dataset: False
# Step:260000 - Loss: 1.82703363895
# ('Wanted to predict: ', 'Brayn')
# ('Got: ', 'Bridn')
# In dataset: False
# Step:270000 - Loss: 1.82830345631
# ('Wanted to predict: ', 'Aries')
# ('Got: ', 'Arion')
# In dataset: True
# Step:280000 - Loss: 1.82997453213
# ('Wanted to predict: ', 'Kyona')
# ('Got: ', 'Kalna')
# In dataset: False
# Step:290000 - Loss: 1.83179271221
# ('Wanted to predict: ', 'Eldar')
# ('Got: ', 'Esiin')
# In dataset: False
# Step:300000 - Loss: 1.83416318893
# ('Wanted to predict: ', 'Jaron')
# ('Got: ', 'Janen')
# In dataset: False
# Step:310000 - Loss: 1.83609080315
# ('Wanted to predict: ', 'Ryaan')
# ('Got: ', 'Ralnn')
# In dataset: False
# Step:320000 - Loss: 1.83844804764
# ('Wanted to predict: ', 'Casia')
# ('Got: ', 'Calia')
# In dataset: True
# Step:330000 - Loss: 1.8404020071
# ('Wanted to predict: ', 'Axcel')
# ('Got: ', 'Arten')
# In dataset: False
# Step:340000 - Loss: 1.84273505211
# ('Wanted to predict: ', 'Emmah')
# ('Got: ', 'Emaih')
# In dataset: False
# Step:350000 - Loss: 1.84530568123
# ('Wanted to predict: ', 'Aliva')
# ('Got: ', 'Anisa')
# In dataset: True
# Step:360000 - Loss: 1.84747266769
# ('Wanted to predict: ', 'Jyden')
# ('Got: ', 'Jaren')
# In dataset: True
# Step:370000 - Loss: 1.84983146191
# ('Wanted to predict: ', 'Rubee')
# ('Got: ', 'Rodie')
# In dataset: True
# Step:380000 - Loss: 1.8520501852
# ('Wanted to predict: ', 'Kalan')
# ('Got: ', 'Kamen')
# In dataset: True
# Step:0 - Loss: 1.85262167454
# ('Wanted to predict: ', 'Alice')
# ('Got: ', 'Aseae')
# In dataset: False
# Step:10000 - Loss: 1.85535919666
# ('Wanted to predict: ', 'Fritz')
# ('Got: ', 'Fratz')
# In dataset: False
# Step:20000 - Loss: 1.85020935535
# ('Wanted to predict: ', 'Lexie')
# ('Got: ', 'Looie')
# In dataset: False
# Step:30000 - Loss: 1.84393429756
# ('Wanted to predict: ', 'Alter')
# ('Got: ', 'Alvor')
# In dataset: False
# Step:40000 - Loss: 1.84030723572
# ('Wanted to predict: ', 'Claud')
# ('Got: ', 'Caars')
# In dataset: False
# Step:50000 - Loss: 1.83817660809
# ('Wanted to predict: ', 'Benno')
# ('Got: ', 'Burny')
# In dataset: False
# Step:60000 - Loss: 1.8358694315
# ('Wanted to predict: ', 'Dawne')
# ('Got: ', 'Darna')
# In dataset: False
# Step:70000 - Loss: 1.83315467834
# ('Wanted to predict: ', 'Norva')
# ('Got: ', 'Nelma')
# In dataset: True
# Step:80000 - Loss: 1.82966530323
# ('Wanted to predict: ', 'Toula')
# ('Got: ', 'Tonda')
# In dataset: True
# Step:90000 - Loss: 1.8259125948
# ('Wanted to predict: ', 'Enoch')
# ('Got: ', 'Elnch')
# In dataset: False
# Step:100000 - Loss: 1.82204532623
# ('Wanted to predict: ', 'Ariel')
# ('Got: ', 'Arlel')
# In dataset: False
# Step:110000 - Loss: 1.81847500801
# ('Wanted to predict: ', 'Linzy')
# ('Got: ', 'Landy')
# In dataset: True
# Step:120000 - Loss: 1.81541204453
# ('Wanted to predict: ', 'Devan')
# ('Got: ', 'Doran')
# In dataset: True
# Step:130000 - Loss: 1.81272041798
# ('Wanted to predict: ', 'Sarah')
# ('Got: ', 'Sanah')
# In dataset: True
# Step:140000 - Loss: 1.81033396721
# ('Wanted to predict: ', 'Jacob')
# ('Got: ', 'Jamob')
# In dataset: False
# Step:150000 - Loss: 1.80810630322
# ('Wanted to predict: ', 'Larri')
# ('Got: ', 'Lirry')
# In dataset: False
# Step:160000 - Loss: 1.80597162247
# ('Wanted to predict: ', 'Arlie')
# ('Got: ', 'Altes')
# In dataset: False
# Step:170000 - Loss: 1.80476176739
# ('Wanted to predict: ', 'Johny')
# ('Got: ', 'Jarny')
# In dataset: False
# Step:180000 - Loss: 1.80411493778
# ('Wanted to predict: ', 'Smita')
# ('Got: ', 'Saita')
# In dataset: False
# Step:190000 - Loss: 1.80397951603
# ('Wanted to predict: ', 'Heidy')
# ('Got: ', 'Haidi')
# In dataset: True
# Step:200000 - Loss: 1.8038226366
# ('Wanted to predict: ', 'Torin')
# ('Got: ', 'Taris')
# In dataset: True
# Step:210000 - Loss: 1.80369997025
# ('Wanted to predict: ', 'Erynn')
# ('Got: ', 'Elica')
# In dataset: True
# Step:220000 - Loss: 1.80358946323
# ('Wanted to predict: ', 'Jovon')
# ('Got: ', 'Janon')
# In dataset: True
# Step:230000 - Loss: 1.80368089676
# ('Wanted to predict: ', 'Dione')
# ('Got: ', 'Daxne')
# In dataset: False
# Step:240000 - Loss: 1.80399167538
# ('Wanted to predict: ', 'Danan')
# ('Got: ', 'Darel')
# In dataset: True
# Step:250000 - Loss: 1.8045541048
# ('Wanted to predict: ', 'Rendy')
# ('Got: ', 'Roeey')
# In dataset: False
# Step:260000 - Loss: 1.80518889427
# ('Wanted to predict: ', 'Brayn')
# ('Got: ', 'Bridn')
# In dataset: False
# Step:270000 - Loss: 1.80591964722
# ('Wanted to predict: ', 'Aries')
# ('Got: ', 'Amial')
# In dataset: False
# Step:280000 - Loss: 1.80689048767
# ('Wanted to predict: ', 'Kyona')
# ('Got: ', 'Kelna')
# In dataset: False
# Step:290000 - Loss: 1.80802190304
# ('Wanted to predict: ', 'Eldar')
# ('Got: ', 'Emion')
# In dataset: False
# Step:300000 - Loss: 1.8095010519
# ('Wanted to predict: ', 'Jaron')
# ('Got: ', 'Jaien')
# In dataset: False
# Step:310000 - Loss: 1.81077694893
# ('Wanted to predict: ', 'Ryaan')
# ('Got: ', 'Raknn')
# In dataset: False
# Step:320000 - Loss: 1.81235301495
# ('Wanted to predict: ', 'Casia')
# ('Got: ', 'Calsa')
# In dataset: False
# Step:330000 - Loss: 1.81368279457
# ('Wanted to predict: ', 'Axcel')
# ('Got: ', 'Artel')
# In dataset: False
# Step:340000 - Loss: 1.81527173519
# ('Wanted to predict: ', 'Emmah')
# ('Got: ', 'Elaih')
# In dataset: False
# Step:350000 - Loss: 1.81703209877
# ('Wanted to predict: ', 'Aliva')
# ('Got: ', 'Aniaa')
# In dataset: False
# Step:360000 - Loss: 1.81854128838
# ('Wanted to predict: ', 'Jyden')
# ('Got: ', 'Jaren')
# In dataset: True
# Step:370000 - Loss: 1.82017242908
# ('Wanted to predict: ', 'Rubee')
# ('Got: ', 'Risie')
# In dataset: False
# Step:380000 - Loss: 1.8217663765
# ('Wanted to predict: ', 'Kalan')
# ('Got: ', 'Kamin')
# In dataset: True
# Step:0 - Loss: 1.82219076157
# ('Wanted to predict: ', 'Alice')
# ('Got: ', 'Ameae')
# In dataset: False
# Step:10000 - Loss: 1.82414329052
# ('Wanted to predict: ', 'Fritz')
# ('Got: ', 'Flatz')
# In dataset: False
# Step:20000 - Loss: 1.82057201862
# ('Wanted to predict: ', 'Lexie')
# ('Got: ', 'Looie')
# In dataset: False
# Step:30000 - Loss: 1.8163421154
# ('Wanted to predict: ', 'Alter')
# ('Got: ', 'Aleor')
# In dataset: False
# Step:40000 - Loss: 1.81390810013
# ('Wanted to predict: ', 'Claud')
# ('Got: ', 'Caerd')
# In dataset: False
# Step:50000 - Loss: 1.81246709824
# ('Wanted to predict: ', 'Benno')
# ('Got: ', 'Brrny')
# In dataset: False
# Step:60000 - Loss: 1.8108522892
# ('Wanted to predict: ', 'Dawne')
# ('Got: ', 'Denna')
# In dataset: True
# Step:70000 - Loss: 1.80899107456
# ('Wanted to predict: ', 'Norva')
# ('Got: ', 'Nelaa')
# In dataset: False
# Step:80000 - Loss: 1.80655872822
# ('Wanted to predict: ', 'Toula')
# ('Got: ', 'Thnla')
# In dataset: False
# Step:90000 - Loss: 1.80395567417
# ('Wanted to predict: ', 'Enoch')
# ('Got: ', 'Erdlh')
# In dataset: False
# Step:100000 - Loss: 1.8012458086
# ('Wanted to predict: ', 'Ariel')
# ('Got: ', 'Arlel')
# In dataset: False
# Step:110000 - Loss: 1.7986805439
# ('Wanted to predict: ', 'Linzy')
# ('Got: ', 'Londy')
# In dataset: False
# Step:120000 - Loss: 1.79649829865
# ('Wanted to predict: ', 'Devan')
# ('Got: ', 'Denan')
# In dataset: False
# Step:130000 - Loss: 1.79453933239
# ('Wanted to predict: ', 'Sarah')
# ('Got: ', 'Sanah')
# In dataset: True
# Step:140000 - Loss: 1.79282879829
# ('Wanted to predict: ', 'Jacob')
# ('Got: ', 'Jarcb')
# In dataset: False
# Step:150000 - Loss: 1.79121673107
# ('Wanted to predict: ', 'Larri')
# ('Got: ', 'Laray')
# In dataset: True
# Step:160000 - Loss: 1.78969609737
# ('Wanted to predict: ', 'Arlie')
# ('Got: ', 'Alien')
# In dataset: True
# Step:170000 - Loss: 1.78884541988
# ('Wanted to predict: ', 'Johny')
# ('Got: ', 'Jarny')
# In dataset: False
# Step:180000 - Loss: 1.78835439682
# ('Wanted to predict: ', 'Smita')
# ('Got: ', 'Saita')
# In dataset: False
# Step:190000 - Loss: 1.78824603558
# ('Wanted to predict: ', 'Heidy')
# ('Got: ', 'Haida')
# In dataset: False
# Step:200000 - Loss: 1.7881141901
# ('Wanted to predict: ', 'Torin')
# ('Got: ', 'Tarie')
# In dataset: True
# Step:210000 - Loss: 1.78802013397
# ('Wanted to predict: ', 'Erynn')
# ('Got: ', 'Elinn')
# In dataset: False
# Step:220000 - Loss: 1.78788757324
# ('Wanted to predict: ', 'Jovon')
# ('Got: ', 'Jason')
# In dataset: True
# Step:230000 - Loss: 1.78794360161
# ('Wanted to predict: ', 'Dione')
# ('Got: ', 'Daane')
# In dataset: False
# Step:240000 - Loss: 1.78814387321
# ('Wanted to predict: ', 'Danan')
# ('Got: ', 'Daree')
# In dataset: False
# Step:250000 - Loss: 1.78854894638
# ('Wanted to predict: ', 'Rendy')
# ('Got: ', 'Roeny')
# In dataset: False
# Step:260000 - Loss: 1.78899598122
# ('Wanted to predict: ', 'Brayn')
# ('Got: ', 'Bridn')
# In dataset: False
# Step:270000 - Loss: 1.78953051567
# ('Wanted to predict: ', 'Aries')
# ('Got: ', 'Astel')
# In dataset: False
# Step:280000 - Loss: 1.79031538963
# ('Wanted to predict: ', 'Kyona')
# ('Got: ', 'Kelna')
# In dataset: False
# Step:290000 - Loss: 1.79113972187
# ('Wanted to predict: ', 'Eldar')
# ('Got: ', 'Edien')
# In dataset: False
# Step:300000 - Loss: 1.79229831696
# ('Wanted to predict: ', 'Jaron')
# ('Got: ', 'Jaien')
# In dataset: False
# Step:310000 - Loss: 1.79326462746
# ('Wanted to predict: ', 'Ryaan')
# ('Got: ', 'Ralnn')
# In dataset: False
# Step:320000 - Loss: 1.79443347454
# ('Wanted to predict: ', 'Casia')
# ('Got: ', 'Calee')
# In dataset: True
# Step:330000 - Loss: 1.79545223713
# ('Wanted to predict: ', 'Axcel')
# ('Got: ', 'Adiel')
# In dataset: True
# Step:340000 - Loss: 1.79665017128
# ('Wanted to predict: ', 'Emmah')
# ('Got: ', 'Emiah')
# In dataset: True
# Step:350000 - Loss: 1.79801356792
# ('Wanted to predict: ', 'Aliva')
# ('Got: ', 'Aliaa')
# In dataset: False
# Step:360000 - Loss: 1.79916787148
# ('Wanted to predict: ', 'Jyden')
# ('Got: ', 'Jaren')
# In dataset: True
# Step:370000 - Loss: 1.80042803288
# ('Wanted to predict: ', 'Rubee')
# ('Got: ', 'Rabin')
# In dataset: False
# Step:380000 - Loss: 1.80169904232
# ('Wanted to predict: ', 'Kalan')
# ('Got: ', 'Kemen')
# In dataset: False
# Step:0 - Loss: 1.80203485489
# ('Wanted to predict: ', 'Alice')
# ('Got: ', 'Ameae')
# In dataset: False
# Step:10000 - Loss: 1.80355274677
# ('Wanted to predict: ', 'Fritz')
# ('Got: ', 'Flatz')
# In dataset: False
# Step:20000 - Loss: 1.80081343651
# ('Wanted to predict: ', 'Lexie')
# ('Got: ', 'Looie')
# In dataset: False
# Step:30000 - Loss: 1.79758477211
# ('Wanted to predict: ', 'Alter')
# ('Got: ', 'Alvon')
# In dataset: True
# Step:40000 - Loss: 1.79573249817
# ('Wanted to predict: ', 'Claud')
# ('Got: ', 'Clerd')
# In dataset: False
# Step:50000 - Loss: 1.79464399815
# ('Wanted to predict: ', 'Benno')
# ('Got: ', 'Brrny')
# In dataset: False
# Step:60000 - Loss: 1.79346632957
# ('Wanted to predict: ', 'Dawne')
# ('Got: ', 'Derna')
# In dataset: True
# Step:70000 - Loss: 1.79206359386
# ('Wanted to predict: ', 'Norva')
# ('Got: ', 'Nelma')
# In dataset: True
# Step:80000 - Loss: 1.7902109623
# ('Wanted to predict: ', 'Toula')
# ('Got: ', 'Thnla')
# In dataset: False
# Step:90000 - Loss: 1.78823101521
# ('Wanted to predict: ', 'Enoch')
# ('Got: ', 'Eddlh')
# In dataset: False
# Step:100000 - Loss: 1.78616023064
# ('Wanted to predict: ', 'Ariel')
# ('Got: ', 'Arlel')
# In dataset: False
# Step:110000 - Loss: 1.78423058987
# ('Wanted to predict: ', 'Linzy')
# ('Got: ', 'Londy')
# In dataset: False
# Step:120000 - Loss: 1.78256952763
# ('Wanted to predict: ', 'Devan')
# ('Got: ', 'Deron')
# In dataset: True
# Step:130000 - Loss: 1.78109514713
# ('Wanted to predict: ', 'Sarah')
# ('Got: ', 'Shnah')
# In dataset: False
# Step:140000 - Loss: 1.77979063988
# ('Wanted to predict: ', 'Jacob')
# ('Got: ', 'Jamkb')
# In dataset: False
# Step:150000 - Loss: 1.77857673168
# ('Wanted to predict: ', 'Larri')
# ('Got: ', 'Lerry')
# In dataset: True
# Step:160000 - Loss: 1.77738630772
# ('Wanted to predict: ', 'Arlie')
# ('Got: ', 'Allen')
# In dataset: True
# Step:170000 - Loss: 1.77673149109
# ('Wanted to predict: ', 'Johny')
# ('Got: ', 'Jorny')
# In dataset: False
# Step:180000 - Loss: 1.77633774281
# ('Wanted to predict: ', 'Smita')
# ('Got: ', 'Saith')
# In dataset: True
# Step:190000 - Loss: 1.77625119686
# ('Wanted to predict: ', 'Heidy')
# ('Got: ', 'Haidi')
# In dataset: True
# Step:200000 - Loss: 1.77614831924
# ('Wanted to predict: ', 'Torin')
# ('Got: ', 'Tarin')
# In dataset: True
# Step:210000 - Loss: 1.77607321739
# ('Wanted to predict: ', 'Erynn')
# ('Got: ', 'Elica')
# In dataset: True
# Step:220000 - Loss: 1.77597463131
# ('Wanted to predict: ', 'Jovon')
# ('Got: ', 'Janon')
# In dataset: True
# Step:230000 - Loss: 1.77599954605
# ('Wanted to predict: ', 'Dione')
# ('Got: ', 'Daxne')
# In dataset: False
# Step:240000 - Loss: 1.77614676952
# ('Wanted to predict: ', 'Danan')
# ('Got: ', 'Daree')
# In dataset: False
# Step:250000 - Loss: 1.77645218372
# ('Wanted to predict: ', 'Rendy')
# ('Got: ', 'Roeny')
# In dataset: False
# Step:260000 - Loss: 1.77681434155
# ('Wanted to predict: ', 'Brayn')
# ('Got: ', 'Bridn')
# In dataset: False
# Step:270000 - Loss: 1.77722227573
# ('Wanted to predict: ', 'Aries')
# ('Got: ', 'Arian')
# In dataset: True
# Step:280000 - Loss: 1.77781653404
# ('Wanted to predict: ', 'Kyona')
# ('Got: ', 'Kelna')
# In dataset: False
# Step:290000 - Loss: 1.7784512043
# ('Wanted to predict: ', 'Eldar')
# ('Got: ', 'Elion')
# In dataset: True
# Step:300000 - Loss: 1.77934575081
# ('Wanted to predict: ', 'Jaron')
# ('Got: ', 'Janen')
# In dataset: False
# Step:310000 - Loss: 1.78011965752
# ('Wanted to predict: ', 'Ryaan')
# ('Got: ', 'Rolnn')
# In dataset: False
# Step:320000 - Loss: 1.78105783463
# ('Wanted to predict: ', 'Casia')
# ('Got: ', 'Chlsa')
# In dataset: False
# Step:330000 - Loss: 1.78186905384
# ('Wanted to predict: ', 'Axcel')
# ('Got: ', 'Arhel')
# In dataset: False
# Step:340000 - Loss: 1.78284478188
# ('Wanted to predict: ', 'Emmah')
# ('Got: ', 'Emiih')
# In dataset: False
# Step:350000 - Loss: 1.78394973278
# ('Wanted to predict: ', 'Aliva')
# ('Got: ', 'Adisa')
# In dataset: True
# Step:360000 - Loss: 1.78489112854
# ('Wanted to predict: ', 'Jyden')
# ('Got: ', 'Jaren')
# In dataset: True
# Step:370000 - Loss: 1.78589618206
# ('Wanted to predict: ', 'Rubee')
# ('Got: ', 'Rabin')
# In dataset: False
# Step:380000 - Loss: 1.78693401814
# ('Wanted to predict: ', 'Kalan')
# ('Got: ', 'Kamen')
# In dataset: True
# Step:0 - Loss: 1.78719294071
# ('Wanted to predict: ', 'Alice')
# ('Got: ', 'Ameae')
# In dataset: False
# Step:10000 - Loss: 1.78843033314
# ('Wanted to predict: ', 'Fritz')
# ('Got: ', 'Franz')
# In dataset: True
# Step:20000 - Loss: 1.78621160984
# ('Wanted to predict: ', 'Lexie')
# ('Got: ', 'Looie')
# In dataset: False
# Step:30000 - Loss: 1.7836316824
# ('Wanted to predict: ', 'Alter')
# ('Got: ', 'Alvon')
# In dataset: True
# Step:40000 - Loss: 1.78211963177
# ('Wanted to predict: ', 'Claud')
# ('Got: ', 'Caerd')
# In dataset: False
# Step:50000 - Loss: 1.78123474121
# ('Wanted to predict: ', 'Benno')
# ('Got: ', 'Brrny')
# In dataset: False
# Step:60000 - Loss: 1.78027641773
# ('Wanted to predict: ', 'Dawne')
# ('Got: ', 'Darna')
# In dataset: False
# Step:70000 - Loss: 1.77913713455
# ('Wanted to predict: ', 'Norva')
# ('Got: ', 'Nelaa')
# In dataset: False
# Step:80000 - Loss: 1.77765417099
# ('Wanted to predict: ', 'Toula')
# ('Got: ', 'Trnna')
# In dataset: False
# Step:90000 - Loss: 1.77604174614
# ('Wanted to predict: ', 'Enoch')
# ('Got: ', 'Elnlh')
# In dataset: False
# Step:100000 - Loss: 1.77436673641
# ('Wanted to predict: ', 'Ariel')
# ('Got: ', 'Arlel')
# In dataset: False
# Step:110000 - Loss: 1.77279937267
# ('Wanted to predict: ', 'Linzy')
# ('Got: ', 'Londy')
# In dataset: False
# Step:120000 - Loss: 1.77144861221
# ('Wanted to predict: ', 'Devan')
# ('Got: ', 'Deron')
# In dataset: True
# Step:130000 - Loss: 1.77024996281
# ('Wanted to predict: ', 'Sarah')
# ('Got: ', 'Sanah')
# In dataset: True
# Step:140000 - Loss: 1.76917731762
# ('Wanted to predict: ', 'Jacob')
# ('Got: ', 'Jamob')
# In dataset: False
# Step:150000 - Loss: 1.76818966866
# ('Wanted to predict: ', 'Larri')
# ('Got: ', 'Lerry')
# In dataset: True
# Step:160000 - Loss: 1.76721346378
# ('Wanted to predict: ', 'Arlie')
# ('Got: ', 'Antes')
# In dataset: False
# Step:170000 - Loss: 1.76666474342
# ('Wanted to predict: ', 'Johny')
# ('Got: ', 'Jasny')
# In dataset: False
# Step:180000 - Loss: 1.76634573936
# ('Wanted to predict: ', 'Smita')
# ('Got: ', 'Saita')
# In dataset: False
# Step:190000 - Loss: 1.766248703
# ('Wanted to predict: ', 'Heidy')
# ('Got: ', 'Haide')
# In dataset: True
# Step:200000 - Loss: 1.76613736153
# ('Wanted to predict: ', 'Torin')
# ('Got: ', 'Tarin')
# In dataset: True
# Step:210000 - Loss: 1.76605677605
# ('Wanted to predict: ', 'Erynn')
# ('Got: ', 'Elina')
# In dataset: True
# Step:220000 - Loss: 1.76596617699
# ('Wanted to predict: ', 'Jovon')
# ('Got: ', 'Jaron')
# In dataset: True
# Step:230000 - Loss: 1.76597929001
# ('Wanted to predict: ', 'Dione')
# ('Got: ', 'Daxne')
# In dataset: False
# Step:240000 - Loss: 1.76608526707
# ('Wanted to predict: ', 'Danan')
# ('Got: ', 'Daren')
# In dataset: True
# Step:250000 - Loss: 1.7663359642
# ('Wanted to predict: ', 'Rendy')
# ('Got: ', 'Raeey')
# In dataset: False
# Step:260000 - Loss: 1.76663482189
# ('Wanted to predict: ', 'Brayn')
# ('Got: ', 'Brydn')
# In dataset: False
# Step:270000 - Loss: 1.76697778702
# ('Wanted to predict: ', 'Aries')
# ('Got: ', 'Arlon')
# In dataset: True
# Step:280000 - Loss: 1.76746964455
# ('Wanted to predict: ', 'Kyona')
# ('Got: ', 'Kelna')
# In dataset: False
# Step:290000 - Loss: 1.76800572872
# ('Wanted to predict: ', 'Eldar')
# ('Got: ', 'Edien')
# In dataset: False
# Step:300000 - Loss: 1.76876068115
# ('Wanted to predict: ', 'Jaron')
# ('Got: ', 'Janen')
# In dataset: False
# Step:310000 - Loss: 1.76941490173
# ('Wanted to predict: ', 'Ryaan')
# ('Got: ', 'Ralnd')
# In dataset: False
# Step:320000 - Loss: 1.77019262314
# ('Wanted to predict: ', 'Casia')
# ('Got: ', 'Calse')
# In dataset: False
# Step:330000 - Loss: 1.77087593079
# ('Wanted to predict: ', 'Axcel')
# ('Got: ', 'Ariel')
# In dataset: True
# Step:340000 - Loss: 1.77169156075
# ('Wanted to predict: ', 'Emmah')
# ('Got: ', 'Emiih')
# In dataset: False
# Step:350000 - Loss: 1.77261960506
# ('Wanted to predict: ', 'Aliva')
# ('Got: ', 'Adiaa')
# In dataset: False
# Step:360000 - Loss: 1.77342569828
# ('Wanted to predict: ', 'Jyden')
# ('Got: ', 'Jaren')
# In dataset: True
# Step:370000 - Loss: 1.77427709103
# ('Wanted to predict: ', 'Rubee')
# ('Got: ', 'Rabin')
# In dataset: False
# Step:380000 - Loss: 1.77516746521
# ('Wanted to predict: ', 'Kalan')
# ('Got: ', 'Kamen')
# In dataset: True
# Step:0 - Loss: 1.77539598942
# ('Wanted to predict: ', 'Alice')
# ('Got: ', 'Ameae')
# In dataset: False
# Step:10000 - Loss: 1.77644824982
# ('Wanted to predict: ', 'Fritz')
# ('Got: ', 'Flatz')
# In dataset: False
# Step:20000 - Loss: 1.77460503578
# ('Wanted to predict: ', 'Lexie')
# ('Got: ', 'Looie')
# In dataset: False
# Step:30000 - Loss: 1.77247333527
# ('Wanted to predict: ', 'Alter')
# ('Got: ', 'Alvon')
# In dataset: True
# Step:40000 - Loss: 1.77121949196
# ('Wanted to predict: ', 'Claud')
# ('Got: ', 'Clerd')
# In dataset: False
# Step:50000 - Loss: 1.77048707008
# ('Wanted to predict: ', 'Benno')
# ('Got: ', 'Brrny')
# In dataset: False
# Step:60000 - Loss: 1.76967275143
# ('Wanted to predict: ', 'Dawne')
# ('Got: ', 'Darna')
# In dataset: False
# Step:70000 - Loss: 1.76870727539
# ('Wanted to predict: ', 'Norva')
# ('Got: ', 'Nelma')
# In dataset: True
# Step:80000 - Loss: 1.76744794846
# ('Wanted to predict: ', 'Toula')
# ('Got: ', 'Trnla')
# In dataset: False
# Step:90000 - Loss: 1.76609826088
# ('Wanted to predict: ', 'Enoch')
# ('Got: ', 'Elnlh')
# In dataset: False
# Step:100000 - Loss: 1.76469957829
# ('Wanted to predict: ', 'Ariel')
# ('Got: ', 'Arlel')
# In dataset: False
# Step:110000 - Loss: 1.76339423656
# ('Wanted to predict: ', 'Linzy')
# ('Got: ', 'Londy')
# In dataset: False
# Step:120000 - Loss: 1.7622692585
# ('Wanted to predict: ', 'Devan')
# ('Got: ', 'Deron')
# In dataset: True
# Step:130000 - Loss: 1.76126766205
# ('Wanted to predict: ', 'Sarah')
# ('Got: ', 'Sanah')
# In dataset: True
# Step:140000 - Loss: 1.76036596298
# ('Wanted to predict: ', 'Jacob')
# ('Got: ', 'Jemob')
# In dataset: False
# Step:150000 - Loss: 1.75952553749
# ('Wanted to predict: ', 'Larri')
# ('Got: ', 'Lerry')
# In dataset: True
# Step:160000 - Loss: 1.75872087479
# ('Wanted to predict: ', 'Arlie')
# ('Got: ', 'Anten')
# In dataset: False
# Step:170000 - Loss: 1.75826454163
# ('Wanted to predict: ', 'Johny')
# ('Got: ', 'Jarny')
# In dataset: False
# Step:180000 - Loss: 1.75799357891
# ('Wanted to predict: ', 'Smita')
# ('Got: ', 'Saisa')
# In dataset: False
# Step:190000 - Loss: 1.75793397427
# ('Wanted to predict: ', 'Heidy')
# ('Got: ', 'Haidi')
# In dataset: True
# Step:200000 - Loss: 1.75785458088
# ('Wanted to predict: ', 'Torin')
# ('Got: ', 'Tarrn')
# In dataset: False
# Step:210000 - Loss: 1.75778746605
# ('Wanted to predict: ', 'Erynn')
# ('Got: ', 'Elinn')
# In dataset: False
# Step:220000 - Loss: 1.75771462917
# ('Wanted to predict: ', 'Jovon')
# ('Got: ', 'Jaron')
# In dataset: True
# Step:230000 - Loss: 1.75774037838
# ('Wanted to predict: ', 'Dione')
# ('Got: ', 'Daxne')
# In dataset: False
# Step:240000 - Loss: 1.757848382
# ('Wanted to predict: ', 'Danan')
# ('Got: ', 'Daren')
# In dataset: True
# Step:250000 - Loss: 1.75806748867
# ('Wanted to predict: ', 'Rendy')
# ('Got: ', 'Ronny')
# In dataset: True
# Step:260000 - Loss: 1.75833296776
# ('Wanted to predict: ', 'Brayn')
# ('Got: ', 'Bridn')
# In dataset: False
# Step:270000 - Loss: 1.75862538815
# ('Wanted to predict: ', 'Aries')
# ('Got: ', 'Ariel')
# In dataset: True
# Step:280000 - Loss: 1.75905680656
# ('Wanted to predict: ', 'Kyona')
# ('Got: ', 'Kelna')
# In dataset: False
# Step:290000 - Loss: 1.75951480865
# ('Wanted to predict: ', 'Eldar')
# ('Got: ', 'Elien')
# In dataset: False
# Step:300000 - Loss: 1.76016616821
# ('Wanted to predict: ', 'Jaron')
# ('Got: ', 'Janen')
# In dataset: False
# Step:310000 - Loss: 1.7607306242
# ('Wanted to predict: ', 'Ryaan')
# ('Got: ', 'Ralnn')
# In dataset: False
# Step:320000 - Loss: 1.76141679287
# ('Wanted to predict: ', 'Casia')
# ('Got: ', 'Calse')
# In dataset: False
# Step:330000 - Loss: 1.7620164156
# ('Wanted to predict: ', 'Axcel')
# ('Got: ', 'Arhel')
# In dataset: False
# Step:340000 - Loss: 1.7627414465
# ('Wanted to predict: ', 'Emmah')
# ('Got: ', 'Emiih')
# In dataset: False
# Step:350000 - Loss: 1.76356053352
# ('Wanted to predict: ', 'Aliva')
# ('Got: ', 'Adina')
# In dataset: True
# Step:360000 - Loss: 1.76428067684
# ('Wanted to predict: ', 'Jyden')
# ('Got: ', 'Jaren')
# In dataset: True
# Step:370000 - Loss: 1.76503419876
# ('Wanted to predict: ', 'Rubee')
# ('Got: ', 'Ribin')
# In dataset: False
# Step:380000 - Loss: 1.76580953598
# ('Wanted to predict: ', 'Kalan')
# ('Got: ', 'Kamem')
# In dataset: False
# Step:0 - Loss: 1.76601159573
# ('Wanted to predict: ', 'Alice')
# ('Got: ', 'Aseae')
# In dataset: False
# Step:10000 - Loss: 1.76694345474
# ('Wanted to predict: ', 'Fritz')
# ('Got: ', 'Flatz')
# In dataset: False
# Step:20000 - Loss: 1.76537930965
# ('Wanted to predict: ', 'Lexie')
# ('Got: ', 'Looie')
# In dataset: False
# Step:30000 - Loss: 1.76355922222
# ('Wanted to predict: ', 'Alter')
# ('Got: ', 'Algor')
# In dataset: False
# Step:40000 - Loss: 1.76250433922
# ('Wanted to predict: ', 'Claud')
# ('Got: ', 'Clerd')
# In dataset: False
# Step:50000 - Loss: 1.76189243793
# ('Wanted to predict: ', 'Benno')
# ('Got: ', 'Brrny')
# In dataset: False
# Step:60000 - Loss: 1.76121199131
# ('Wanted to predict: ', 'Dawne')
# ('Got: ', 'Derna')
# In dataset: True
# Step:70000 - Loss: 1.76041018963
# ('Wanted to predict: ', 'Norva')
# ('Got: ', 'Nerma')
# In dataset: True
# Step:80000 - Loss: 1.75935316086
# ('Wanted to predict: ', 'Toula')
# ('Got: ', 'Tenna')
# In dataset: True
# Step:90000 - Loss: 1.75820684433
# ('Wanted to predict: ', 'Enoch')
# ('Got: ', 'Eldlh')
# In dataset: False
# Step:100000 - Loss: 1.75701677799
# ('Wanted to predict: ', 'Ariel')
# ('Got: ', 'Arlel')
# In dataset: False
# Step:110000 - Loss: 1.7559056282
# ('Wanted to predict: ', 'Linzy')
# ('Got: ', 'Lendy')
# In dataset: True
# Step:120000 - Loss: 1.75494754314
# ('Wanted to predict: ', 'Devan')
# ('Got: ', 'Deron')
# In dataset: True
# Step:130000 - Loss: 1.75408899784
# ('Wanted to predict: ', 'Sarah')
# ('Got: ', 'Sanah')
# In dataset: True
# Step:140000 - Loss: 1.75332319736
# ('Wanted to predict: ', 'Jacob')
# ('Got: ', 'Jemob')
# In dataset: False
# Step:150000 - Loss: 1.75261592865
# ('Wanted to predict: ', 'Larri')
# ('Got: ', 'Lorry')
# In dataset: True
# Step:160000 - Loss: 1.75192737579
# ('Wanted to predict: ', 'Arlie')
# ('Got: ', 'Antin')
# In dataset: False
# Step:170000 - Loss: 1.75153946877
# ('Wanted to predict: ', 'Johny')
# ('Got: ', 'Jasny')
# In dataset: False
# Step:180000 - Loss: 1.75130915642
# ('Wanted to predict: ', 'Smita')
# ('Got: ', 'Saith')
# In dataset: True
# Step:190000 - Loss: 1.75124704838
# ('Wanted to predict: ', 'Heidy')
# ('Got: ', 'Haidi')
# In dataset: True
# Step:200000 - Loss: 1.75117743015
# ('Wanted to predict: ', 'Torin')
# ('Got: ', 'Taris')
# In dataset: True
# Step:210000 - Loss: 1.75111830235
# ('Wanted to predict: ', 'Erynn')
# ('Got: ', 'Elinn')
# In dataset: False
# Step:220000 - Loss: 1.75106287003
# ('Wanted to predict: ', 'Jovon')
# ('Got: ', 'Jaran')
# In dataset: True
# Step:230000 - Loss: 1.75108361244
# ('Wanted to predict: ', 'Dione')
# ('Got: ', 'Daane')
# In dataset: False
# Step:240000 - Loss: 1.75118470192
# ('Wanted to predict: ', 'Danan')
# ('Got: ', 'Daree')
# In dataset: False
# Step:250000 - Loss: 1.75138139725
# ('Wanted to predict: ', 'Rendy')
# ('Got: ', 'Ranny')
# In dataset: True
# Step:260000 - Loss: 1.75160777569
# ('Wanted to predict: ', 'Brayn')
# ('Got: ', 'Bridn')
# In dataset: False
# Step:270000 - Loss: 1.75187337399
# ('Wanted to predict: ', 'Aries')
# ('Got: ', 'Arlel')
# In dataset: False
# Step:280000 - Loss: 1.75225734711
# ('Wanted to predict: ', 'Kyona')
# ('Got: ', 'Kelna')
# In dataset: False
# Step:290000 - Loss: 1.75265622139
# ('Wanted to predict: ', 'Eldar')
# ('Got: ', 'Elion')
# In dataset: True
# Step:300000 - Loss: 1.75321304798
# ('Wanted to predict: ', 'Jaron')
# ('Got: ', 'Janen')
# In dataset: False
# Step:310000 - Loss: 1.75371098518
# ('Wanted to predict: ', 'Ryaan')
# ('Got: ', 'Ralnn')
# In dataset: False
# Step:320000 - Loss: 1.75431835651
# ('Wanted to predict: ', 'Casia')
# ('Got: ', 'Calse')
# In dataset: False
# Step:330000 - Loss: 1.75485634804
# ('Wanted to predict: ', 'Axcel')
# ('Got: ', 'Ariel')
# In dataset: True
# Step:340000 - Loss: 1.75550961494
# ('Wanted to predict: ', 'Emmah')
# ('Got: ', 'Emiir')
# In dataset: False
# Step:350000 - Loss: 1.75624346733
# ('Wanted to predict: ', 'Aliva')
# ('Got: ', 'Adiaa')
# In dataset: False
# Step:360000 - Loss: 1.75689685345
# ('Wanted to predict: ', 'Jyden')
# ('Got: ', 'Jaren')
# In dataset: True
# Step:370000 - Loss: 1.75757563114
# ('Wanted to predict: ', 'Rubee')
# ('Got: ', 'Rabin')
# In dataset: False
# Step:380000 - Loss: 1.75828588009
# ('Wanted to predict: ', 'Kalan')
# ('Got: ', 'Kamen')
# In dataset: True
# Step:0 - Loss: 1.75847005844
# ('Wanted to predict: ', 'Alice')
# ('Got: ', 'Aseae')
# In dataset: False
# Step:10000 - Loss: 1.75930178165
# ('Wanted to predict: ', 'Fritz')
# ('Got: ', 'Fratz')
# In dataset: False
# Step:20000 - Loss: 1.75792682171
# ('Wanted to predict: ', 'Lexie')
# ('Got: ', 'Looie')
# In dataset: False
# Step:30000 - Loss: 1.75634288788
# ('Wanted to predict: ', 'Alter')
# ('Got: ', 'Aldor')
# In dataset: True
# Step:40000 - Loss: 1.75543582439
# ('Wanted to predict: ', 'Claud')
# ('Got: ', 'Clerd')
# In dataset: False
# Step:50000 - Loss: 1.75491309166
# ('Wanted to predict: ', 'Benno')
# ('Got: ', 'Burny')
# In dataset: False
# Step:60000 - Loss: 1.75432920456
# ('Wanted to predict: ', 'Dawne')
# ('Got: ', 'Derna')
# In dataset: True
# Step:70000 - Loss: 1.75363957882
# ('Wanted to predict: ', 'Norva')
# ('Got: ', 'Nelma')
# In dataset: True
# Step:80000 - Loss: 1.75271224976
# ('Wanted to predict: ', 'Toula')
# ('Got: ', 'Trnla')
# In dataset: False
# Step:90000 - Loss: 1.75171804428
# ('Wanted to predict: ', 'Enoch')
# ('Got: ', 'Eloch')
# In dataset: False
# Step:100000 - Loss: 1.75067782402
# ('Wanted to predict: ', 'Ariel')
# ('Got: ', 'Allel')
# In dataset: False
# Step:110000 - Loss: 1.74970626831
# ('Wanted to predict: ', 'Linzy')
# ('Got: ', 'Loldy')
# In dataset: False
# Step:120000 - Loss: 1.74887430668
# ('Wanted to predict: ', 'Devan')
# ('Got: ', 'Denon')
# In dataset: True
# Step:130000 - Loss: 1.74813914299
# ('Wanted to predict: ', 'Sarah')
# ('Got: ', 'Sanah')
# In dataset: True
# Step:140000 - Loss: 1.74748134613
# ('Wanted to predict: ', 'Jacob')
# ('Got: ', 'Jomkb')
# In dataset: False
# Step:150000 - Loss: 1.74688887596
# ('Wanted to predict: ', 'Larri')
# ('Got: ', 'Liriy')
# In dataset: False
# Step:160000 - Loss: 1.74628603458
# ('Wanted to predict: ', 'Arlie')
# ('Got: ', 'Alden')
# In dataset: True
# Step:170000 - Loss: 1.74595141411
# ('Wanted to predict: ', 'Johny')
# ('Got: ', 'Jarny')
# In dataset: False
# Step:180000 - Loss: 1.74574697018
# ('Wanted to predict: ', 'Smita')
# ('Got: ', 'Saith')
# In dataset: True
# Step:190000 - Loss: 1.7456959486
# ('Wanted to predict: ', 'Heidy')
# ('Got: ', 'Haidi')
# In dataset: True
# Step:200000 - Loss: 1.74563789368
# ('Wanted to predict: ', 'Torin')
# ('Got: ', 'Tarrn')
# In dataset: False
# Step:210000 - Loss: 1.74558711052
# ('Wanted to predict: ', 'Erynn')
# ('Got: ', 'Elica')
# In dataset: True
# Step:220000 - Loss: 1.74553263187
# ('Wanted to predict: ', 'Jovon')
# ('Got: ', 'Jaron')
# In dataset: True
# Step:230000 - Loss: 1.74554085732
# ('Wanted to predict: ', 'Dione')
# ('Got: ', 'Daxne')
# In dataset: False
# Step:240000 - Loss: 1.74562358856
# ('Wanted to predict: ', 'Danan')
# ('Got: ', 'Darel')
# In dataset: True
# Step:250000 - Loss: 1.74580109119
# ('Wanted to predict: ', 'Rendy')
# ('Got: ', 'Ronny')
# In dataset: True
# Step:260000 - Loss: 1.7460089922
# ('Wanted to predict: ', 'Brayn')
# ('Got: ', 'Bridn')
# In dataset: False
# Step:270000 - Loss: 1.7462438345
# ('Wanted to predict: ', 'Aries')
# ('Got: ', 'Allal')
# In dataset: False
# Step:280000 - Loss: 1.74658703804
# ('Wanted to predict: ', 'Kyona')
# ('Got: ', 'Kalna')
# In dataset: False
# Step:290000 - Loss: 1.74695408344
# ('Wanted to predict: ', 'Eldar')
# ('Got: ', 'Elion')
# In dataset: True
# Step:300000 - Loss: 1.74745965004
# ('Wanted to predict: ', 'Jaron')
# ('Got: ', 'Jayen')
# In dataset: True
# Step:310000 - Loss: 1.7479108572
# ('Wanted to predict: ', 'Ryaan')
# ('Got: ', 'Ralnn')
# In dataset: False
# Step:320000 - Loss: 1.74845468998
# ('Wanted to predict: ', 'Casia')
# ('Got: ', 'Calsa')
# In dataset: False
# Step:330000 - Loss: 1.74895119667
# ('Wanted to predict: ', 'Axcel')
# ('Got: ', 'Ariel')
# In dataset: True
# Step:340000 - Loss: 1.74953711033
# ('Wanted to predict: ', 'Emmah')
# ('Got: ', 'Emiir')
# In dataset: False
# Step:350000 - Loss: 1.75019466877
# ('Wanted to predict: ', 'Aliva')
# ('Got: ', 'Adika')
# In dataset: True
# Step:360000 - Loss: 1.7507827282
# ('Wanted to predict: ', 'Jyden')
# ('Got: ', 'Jaron')
# In dataset: True
# Step:370000 - Loss: 1.75139915943
# ('Wanted to predict: ', 'Rubee')
# ('Got: ', 'Rabin')
# In dataset: False
# Step:380000 - Loss: 1.75203442574
# ('Wanted to predict: ', 'Kalan')
# ('Got: ', 'Kamen')
# In dataset: True
# Step:0 - Loss: 1.75220143795
# ('Wanted to predict: ', 'Alice')
# ('Got: ', 'Aseae')
# In dataset: False
# Step:10000 - Loss: 1.75295996666
# ('Wanted to predict: ', 'Fritz')
# ('Got: ', 'Fratz')
# In dataset: False
# Step:20000 - Loss: 1.75175559521
# ('Wanted to predict: ', 'Lexie')
# ('Got: ', 'Looie')
# In dataset: False
# Step:30000 - Loss: 1.75035429001
# ('Wanted to predict: ', 'Alter')
# ('Got: ', 'Alvon')
# In dataset: True
# Step:40000 - Loss: 1.74955761433
# ('Wanted to predict: ', 'Claud')
# ('Got: ', 'Caeid')
# In dataset: False
# Step:50000 - Loss: 1.74908936024
# ('Wanted to predict: ', 'Benno')
# ('Got: ', 'Berny')
# In dataset: True
# Step:60000 - Loss: 1.74857580662
# ('Wanted to predict: ', 'Dawne')
# ('Got: ', 'Derna')
# In dataset: True
# Step:70000 - Loss: 1.74795842171
# ('Wanted to predict: ', 'Norva')
# ('Got: ', 'Nerma')
# In dataset: True
# Step:80000 - Loss: 1.74714398384
# ('Wanted to predict: ', 'Toula')
# ('Got: ', 'Tenna')
# In dataset: True
# Step:90000 - Loss: 1.74625396729
# ('Wanted to predict: ', 'Enoch')
# ('Got: ', 'Elnch')
# In dataset: False
# Step:100000 - Loss: 1.74533879757
# ('Wanted to predict: ', 'Ariel')
# ('Got: ', 'Anlel')
# In dataset: False
# Step:110000 - Loss: 1.74448156357
# ('Wanted to predict: ', 'Linzy')
# ('Got: ', 'Londy')
# In dataset: False
# Step:120000 - Loss: 1.74373447895
# ('Wanted to predict: ', 'Devan')
# ('Got: ', 'Denon')
# In dataset: True
# Step:130000 - Loss: 1.74307274818
# ('Wanted to predict: ', 'Sarah')
# ('Got: ', 'Sanah')
# In dataset: True
# Step:140000 - Loss: 1.74248671532
# ('Wanted to predict: ', 'Jacob')
# ('Got: ', 'Jemob')
# In dataset: False
# Step:150000 - Loss: 1.74195110798
# ('Wanted to predict: ', 'Larri')
# ('Got: ', 'Larry')
# In dataset: True
# Step:160000 - Loss: 1.74141955376
# ('Wanted to predict: ', 'Arlie')
# ('Got: ', 'Alles')
# In dataset: False
# Step:170000 - Loss: 1.74111127853
# ('Wanted to predict: ', 'Johny')
# ('Got: ', 'Jasny')
# In dataset: False
# Step:180000 - Loss: 1.74092793465
# ('Wanted to predict: ', 'Smita')
# ('Got: ', 'Saith')
# In dataset: True
# Step:190000 - Loss: 1.74089038372
# ('Wanted to predict: ', 'Heidy')
# ('Got: ', 'Haidi')
# In dataset: True
# Step:200000 - Loss: 1.74083793163
# ('Wanted to predict: ', 'Torin')
# ('Got: ', 'Tarrn')
# In dataset: False
# Step:210000 - Loss: 1.74079704285
# ('Wanted to predict: ', 'Erynn')
# ('Got: ', 'Elinn')
# In dataset: False
# Step:220000 - Loss: 1.74074089527
# ('Wanted to predict: ', 'Jovon')
# ('Got: ', 'Jaron')
# In dataset: True
# Step:230000 - Loss: 1.74075770378
# ('Wanted to predict: ', 'Dione')
# ('Got: ', 'Daxne')
# In dataset: False
# Step:240000 - Loss: 1.74083161354
# ('Wanted to predict: ', 'Danan')
# ('Got: ', 'Daree')
# In dataset: False
# Step:250000 - Loss: 1.74098408222
# ('Wanted to predict: ', 'Rendy')
# ('Got: ', 'Ronei')
# In dataset: False
# Step:260000 - Loss: 1.74117159843
# ('Wanted to predict: ', 'Brayn')
# ('Got: ', 'Bridn')
# In dataset: False
# Step:270000 - Loss: 1.74138009548
# ('Wanted to predict: ', 'Aries')
# ('Got: ', 'Aricn')
# In dataset: False
# Step:280000 - Loss: 1.74169492722
# ('Wanted to predict: ', 'Kyona')
# ('Got: ', 'Kelna')
# In dataset: False
# Step:290000 - Loss: 1.74202001095
# ('Wanted to predict: ', 'Eldar')
# ('Got: ', 'Elion')
# In dataset: True
# Step:300000 - Loss: 1.74247479439
# ('Wanted to predict: ', 'Jaron')
# ('Got: ', 'Janen')
# In dataset: False
# Step:310000 - Loss: 1.74289023876
# ('Wanted to predict: ', 'Ryaan')
# ('Got: ', 'Ralnl')
# In dataset: False
# Step:320000 - Loss: 1.74337482452
# ('Wanted to predict: ', 'Casia')
# ('Got: ', 'Calsa')
# In dataset: False
# Step:330000 - Loss: 1.74381196499
# ('Wanted to predict: ', 'Axcel')
# ('Got: ', 'Arxel')
# In dataset: False
# Step:340000 - Loss: 1.74433982372
# ('Wanted to predict: ', 'Emmah')
# ('Got: ', 'Eliar')
# In dataset: False
# Step:350000 - Loss: 1.74493598938
# ('Wanted to predict: ', 'Aliva')
# ('Got: ', 'Adina')
# In dataset: True
# Step:360000 - Loss: 1.74545621872
# ('Wanted to predict: ', 'Jyden')
# ('Got: ', 'Jaren')
# In dataset: True
# Step:370000 - Loss: 1.74600338936
# ('Wanted to predict: ', 'Rubee')
# ('Got: ', 'Rabin')
# In dataset: False
# Step:380000 - Loss: 1.74657702446
# ('Wanted to predict: ', 'Kalan')
# ('Got: ', 'Kamen')
# In dataset: True
# Step:0 - Loss: 1.74672579765
# ('Wanted to predict: ', 'Alice')
# ('Got: ', 'Asese')
# In dataset: False
# Step:10000 - Loss: 1.74741077423
# ('Wanted to predict: ', 'Fritz')
# ('Got: ', 'Fratz')
# In dataset: False
# Step:20000 - Loss: 1.74633085728
# ('Wanted to predict: ', 'Lexie')
# ('Got: ', 'Looie')
# In dataset: False
# Step:30000 - Loss: 1.74507331848
# ('Wanted to predict: ', 'Alter')
# ('Got: ', 'Aleor')
# In dataset: False
# Step:40000 - Loss: 1.74435138702
# ('Wanted to predict: ', 'Claud')
# ('Got: ', 'Clerd')
# In dataset: False
# Step:50000 - Loss: 1.74394536018
# ('Wanted to predict: ', 'Benno')
# ('Got: ', 'Berny')
# In dataset: True
# Step:60000 - Loss: 1.74347925186
# ('Wanted to predict: ', 'Dawne')
# ('Got: ', 'Darna')
# In dataset: False
# Step:70000 - Loss: 1.74293291569
# ('Wanted to predict: ', 'Norva')
# ('Got: ', 'Nerma')
# In dataset: True
# Step:80000 - Loss: 1.74220645428
# ('Wanted to predict: ', 'Toula')
# ('Got: ', 'Trnla')
# In dataset: False
# Step:90000 - Loss: 1.74141275883
# ('Wanted to predict: ', 'Enoch')
# ('Got: ', 'Elnlh')
# In dataset: False
# Step:100000 - Loss: 1.74058449268
# ('Wanted to predict: ', 'Ariel')
# ('Got: ', 'Anlel')
# In dataset: False
# Step:110000 - Loss: 1.73981320858
# ('Wanted to predict: ', 'Linzy')
# ('Got: ', 'Londy')
# In dataset: False
# Step:120000 - Loss: 1.73914921284
# ('Wanted to predict: ', 'Devan')
# ('Got: ', 'Deron')
# In dataset: True
# Step:130000 - Loss: 1.73856043816
# ('Wanted to predict: ', 'Sarah')
# ('Got: ', 'Sanah')
# In dataset: True
# Step:140000 - Loss: 1.73804032803
# ('Wanted to predict: ', 'Jacob')
# ('Got: ', 'Jamkb')
# In dataset: False
# Step:150000 - Loss: 1.73756182194
# ('Wanted to predict: ', 'Larri')
# ('Got: ', 'Lerry')
# In dataset: True
# Step:160000 - Loss: 1.73708021641
# ('Wanted to predict: ', 'Arlie')
# ('Got: ', 'Alten')
# In dataset: True
# Step:170000 - Loss: 1.7368170023
# ('Wanted to predict: ', 'Johny')
# ('Got: ', 'Jasny')
# In dataset: False
# Step:180000 - Loss: 1.73666906357
# ('Wanted to predict: ', 'Smita')
# ('Got: ', 'Saith')
# In dataset: True
# Step:190000 - Loss: 1.73663401604
# ('Wanted to predict: ', 'Heidy')
# ('Got: ', 'Haidi')
# In dataset: True
# Step:200000 - Loss: 1.73658967018
# ('Wanted to predict: ', 'Torin')
# ('Got: ', 'Tarin')
# In dataset: True
# Step:210000 - Loss: 1.7365655899
# ('Wanted to predict: ', 'Erynn')
# ('Got: ', 'Elina')
# In dataset: True
# Step:220000 - Loss: 1.73653078079
# ('Wanted to predict: ', 'Jovon')
# ('Got: ', 'Jaron')
# In dataset: True
# Step:230000 - Loss: 1.73655867577
# ('Wanted to predict: ', 'Dione')
# ('Got: ', 'Daxne')
# In dataset: False
# Step:240000 - Loss: 1.73663592339
# ('Wanted to predict: ', 'Danan')
# ('Got: ', 'Darel')
# In dataset: True
# Step:250000 - Loss: 1.73677325249
# ('Wanted to predict: ', 'Rendy')
# ('Got: ', 'Roney')
# In dataset: True
# Step:260000 - Loss: 1.73693478107
# ('Wanted to predict: ', 'Brayn')
# ('Got: ', 'Brydn')
# In dataset: False
# Step:270000 - Loss: 1.7371275425
# ('Wanted to predict: ', 'Aries')
# ('Got: ', 'Arial')
# In dataset: True
# Step:280000 - Loss: 1.73741388321
# ('Wanted to predict: ', 'Kyona')
# ('Got: ', 'Kelna')
# In dataset: False
# Step:290000 - Loss: 1.73771941662
# ('Wanted to predict: ', 'Eldar')
# ('Got: ', 'Elior')
# In dataset: True
# Step:300000 - Loss: 1.73814857006
# ('Wanted to predict: ', 'Jaron')
# ('Got: ', 'Janen')
# In dataset: False
# Step:310000 - Loss: 1.73852813244
# ('Wanted to predict: ', 'Ryaan')
# ('Got: ', 'Ralnd')
# In dataset: False
# Step:320000 - Loss: 1.73898375034
# ('Wanted to predict: ', 'Casia')
# ('Got: ', 'Calea')
# In dataset: True
# Step:330000 - Loss: 1.73939657211
# ('Wanted to predict: ', 'Axcel')
# ('Got: ', 'Asiel')
# In dataset: True
# Step:340000 - Loss: 1.73988449574
# ('Wanted to predict: ', 'Emmah')
# ('Got: ', 'Eloih')
# In dataset: False
# Step:350000 - Loss: 1.74043226242
# ('Wanted to predict: ', 'Aliva')
# ('Got: ', 'Adiaa')
# In dataset: False
# Step:360000 - Loss: 1.74090993404
# ('Wanted to predict: ', 'Jyden')
# ('Got: ', 'Jaren')
# In dataset: True
# Step:370000 - Loss: 1.74140942097
# ('Wanted to predict: ', 'Rubee')
# ('Got: ', 'Ribin')
# In dataset: False
# Step:380000 - Loss: 1.74194777012
# ('Wanted to predict: ', 'Kalan')
# ('Got: ', 'Kamen')
# In dataset: True
# Step:0 - Loss: 1.74208676815
# ('Wanted to predict: ', 'Alice')
# ('Got: ', 'Ameye')
# In dataset: False
# Step:10000 - Loss: 1.7427188158
# ('Wanted to predict: ', 'Fritz')
# ('Got: ', 'Fratz')
# In dataset: False
# Step:20000 - Loss: 1.74175000191
# ('Wanted to predict: ', 'Lexie')
# ('Got: ', 'Looie')
# In dataset: False
# Step:30000 - Loss: 1.74061799049
# ('Wanted to predict: ', 'Alter')
# ('Got: ', 'Alvon')
# In dataset: True
# Step:40000 - Loss: 1.73997807503
# ('Wanted to predict: ', 'Claud')
# ('Got: ', 'Caeid')
# In dataset: False
# Step:50000 - Loss: 1.73963034153
# ('Wanted to predict: ', 'Benno')
# ('Got: ', 'Burny')
# In dataset: False
# Step:60000 - Loss: 1.73921966553
# ('Wanted to predict: ', 'Dawne')
# ('Got: ', 'Darna')
# In dataset: False
# Step:70000 - Loss: 1.73873388767
# ('Wanted to predict: ', 'Norva')
# ('Got: ', 'Nelma')
# In dataset: True
# Step:80000 - Loss: 1.73808288574
# ('Wanted to predict: ', 'Toula')
# ('Got: ', 'Trnla')
# In dataset: False
# Step:90000 - Loss: 1.73736429214
# ('Wanted to predict: ', 'Enoch')
# ('Got: ', 'Elolh')
# In dataset: False
# Step:100000 - Loss: 1.73661637306
# ('Wanted to predict: ', 'Ariel')
# ('Got: ', 'Anlel')
# In dataset: False
# Step:110000 - Loss: 1.73590672016
# ('Wanted to predict: ', 'Linzy')
# ('Got: ', 'Londa')
# In dataset: True
# Step:120000 - Loss: 1.7353028059
# ('Wanted to predict: ', 'Devan')
# ('Got: ', 'Daron')
# In dataset: True
# Step:130000 - Loss: 1.73476958275
# ('Wanted to predict: ', 'Sarah')
# ('Got: ', 'Sanah')
# In dataset: True
# Step:140000 - Loss: 1.73429632187
# ('Wanted to predict: ', 'Jacob')
# ('Got: ', 'Jamkb')
# In dataset: False
# Step:150000 - Loss: 1.73386287689
# ('Wanted to predict: ', 'Larri')
# ('Got: ', 'Lerry')
# In dataset: True
# Step:160000 - Loss: 1.73342859745
# ('Wanted to predict: ', 'Arlie')
# ('Got: ', 'Alden')
# In dataset: True
# Step:170000 - Loss: 1.73319482803
# ('Wanted to predict: ', 'Johny')
# ('Got: ', 'Jasny')
# In dataset: False
# Step:180000 - Loss: 1.73305678368
# ('Wanted to predict: ', 'Smita')
# ('Got: ', 'Saith')
# In dataset: True
# Step:190000 - Loss: 1.73303902149
# ('Wanted to predict: ', 'Heidy')
# ('Got: ', 'Haidi')
# In dataset: True
# Step:200000 - Loss: 1.73301100731
# ('Wanted to predict: ', 'Torin')
# ('Got: ', 'Tarie')
# In dataset: True
# Step:210000 - Loss: 1.73299157619
# ('Wanted to predict: ', 'Erynn')
# ('Got: ', 'Elina')
# In dataset: True
# Step:220000 - Loss: 1.73295712471
# ('Wanted to predict: ', 'Jovon')
# ('Got: ', 'Jaron')
# In dataset: True
# Step:230000 - Loss: 1.73297798634
# ('Wanted to predict: ', 'Dione')
# ('Got: ', 'Daxne')
# In dataset: False
# Step:240000 - Loss: 1.73304021358
# ('Wanted to predict: ', 'Danan')
# ('Got: ', 'Daree')
# In dataset: False
# Step:250000 - Loss: 1.7331713438
# ('Wanted to predict: ', 'Rendy')
# ('Got: ', 'Roeei')
# In dataset: False
# Step:260000 - Loss: 1.73333024979
# ('Wanted to predict: ', 'Brayn')
# ('Got: ', 'Bridn')
# In dataset: False
# Step:270000 - Loss: 1.7335139513
# ('Wanted to predict: ', 'Aries')
# ('Got: ', 'Arial')
# In dataset: True
# Step:280000 - Loss: 1.73377490044
# ('Wanted to predict: ', 'Kyona')
# ('Got: ', 'Kelna')
# In dataset: False
# Step:290000 - Loss: 1.73405241966
# ('Wanted to predict: ', 'Eldar')
# ('Got: ', 'Eliir')
# In dataset: False
# Step:300000 - Loss: 1.73444759846
# ('Wanted to predict: ', 'Jaron')
# ('Got: ', 'Jaien')
# In dataset: False
# Step:310000 - Loss: 1.73479509354
# ('Wanted to predict: ', 'Ryaan')
# ('Got: ', 'Ralnn')
# In dataset: False
# Step:320000 - Loss: 1.73520982265
# ('Wanted to predict: ', 'Casia')
# ('Got: ', 'Calsa')
# In dataset: False
# Step:330000 - Loss: 1.73558056355
# ('Wanted to predict: ', 'Axcel')
# ('Got: ', 'Ariel')
# In dataset: True
# Step:340000 - Loss: 1.73603272438
# ('Wanted to predict: ', 'Emmah')
# ('Got: ', 'Eliir')
# In dataset: False
# Step:350000 - Loss: 1.73652946949
# ('Wanted to predict: ', 'Aliva')
# ('Got: ', 'Adiya')
# In dataset: True
# Step:360000 - Loss: 1.7369800806
# ...
# In dataset: False
# Step:10000 - Loss: 1.72600650787
# ('Wanted to predict: ', 'Fritz')
# ('Got: ', 'Fratz')
# In dataset: False
# Step:20000 - Loss: 1.72534918785
# ('Wanted to predict: ', 'Lexie')
# ('Got: ', 'Looie')
# In dataset: False
# Step:30000 - Loss: 1.7245824337
# ('Wanted to predict: ', 'Alter')
# ('Got: ', 'Arvon')
# In dataset: True
# Step:40000 - Loss: 1.72415149212
# ('Wanted to predict: ', 'Claud')
# ('Got: ', 'Caers')
# In dataset: False
# Step:50000 - Loss: 1.72392058372
# ('Wanted to predict: ', 'Benno')
# ('Got: ', 'Burny')
# In dataset: False
# Step:60000 - Loss: 1.7236546278
# ('Wanted to predict: ', 'Dawne')
# ('Got: ', 'Darna')
# In dataset: False
# Step:70000 - Loss: 1.72333145142
# ('Wanted to predict: ', 'Norva')
# ('Got: ', 'Nerma')
# In dataset: True
# Step:80000 - Loss: 1.7228962183
# ('Wanted to predict: ', 'Toula')
# ('Got: ', 'Thnla')
# In dataset: False
# Step:90000 - Loss: 1.72241258621
# ('Wanted to predict: ', 'Enoch')
# ('Got: ', 'Elnlh')
# In dataset: False
# Step:100000 - Loss: 1.72190713882
# ('Wanted to predict: ', 'Ariel')
# ('Got: ', 'Allel')
# In dataset: False
# Step:110000 - Loss: 1.72143232822
# ('Wanted to predict: ', 'Linzy')
# ('Got: ', 'Londy')
# In dataset: False
# Step:120000 - Loss: 1.72102594376
# ('Wanted to predict: ', 'Devan')
# ('Got: ', 'Denon')
# In dataset: True
# Step:130000 - Loss: 1.7206594944
# ('Wanted to predict: ', 'Sarah')
# ('Got: ', 'Sanah')
# In dataset: True
# Step:140000 - Loss: 1.7203438282
# ('Wanted to predict: ', 'Jacob')
# ('Got: ', 'Jamib')
# In dataset: False
# Step:150000 - Loss: 1.72005319595
# ('Wanted to predict: ', 'Larri')
# ('Got: ', 'Liriy')
# In dataset: False
# Step:160000 - Loss: 1.71976113319
# ('Wanted to predict: ', 'Arlie')
# ('Got: ', 'Aldis')
# In dataset: True
# Step:170000 - Loss: 1.71960997581
# ('Wanted to predict: ', 'Johny')
# ('Got: ', 'Jasne')
# In dataset: False
# Step:180000 - Loss: 1.71952092648
# ('Wanted to predict: ', 'Smita')
# ('Got: ', 'Saith')
# In dataset: True
# Step:190000 - Loss: 1.71951043606
# ('Wanted to predict: ', 'Heidy')
# ('Got: ', 'Haidi')
# In dataset: True
# Step:200000 - Loss: 1.71948993206
# ('Wanted to predict: ', 'Torin')
# ('Got: ', 'Tarie')
# In dataset: True
# Step:210000 - Loss: 1.71948647499
# ('Wanted to predict: ', 'Erynn')
# ('Got: ', 'Elicn')
# In dataset: False
# Step:220000 - Loss: 1.71947324276
# ('Wanted to predict: ', 'Jovon')
# ('Got: ', 'Jaron')
# In dataset: True
# Step:230000 - Loss: 1.71949923038
# ('Wanted to predict: ', 'Dione')
# ('Got: ', 'Daxne')
# In dataset: False
# Step:240000 - Loss: 1.71955144405
# ('Wanted to predict: ', 'Danan')
# ('Got: ', 'Darey')
# In dataset: True
# Step:250000 - Loss: 1.71965587139
# ('Wanted to predict: ', 'Rendy')
# ('Got: ', 'Roney')
# In dataset: True
# Step:260000 - Loss: 1.71977186203
# ('Wanted to predict: ', 'Brayn')
# ('Got: ', 'Bridn')
# In dataset: False
# Step:270000 - Loss: 1.71990644932
# ('Wanted to predict: ', 'Aries')
# ('Got: ', 'Amian')
# In dataset: False
# Step:280000 - Loss: 1.72010016441
# ('Wanted to predict: ', 'Kyona')
# ('Got: ', 'Kelna')
# In dataset: False
# Step:290000 - Loss: 1.7203053236
# ('Wanted to predict: ', 'Eldar')
# ('Got: ', 'Elien')
# In dataset: False
# Step:300000 - Loss: 1.72058737278
# ('Wanted to predict: ', 'Jaron')
# ('Got: ', 'Jaien')
# In dataset: False
# Step:310000 - Loss: 1.72084236145
# ('Wanted to predict: ', 'Ryaan')
# ('Got: ', 'Ralnd')
# In dataset: False
# Step:320000 - Loss: 1.72114348412
# ('Wanted to predict: ', 'Casia')
# ('Got: ', 'Calea')
# In dataset: True
# Step:330000 - Loss: 1.7214179039
# ('Wanted to predict: ', 'Axcel')
# ('Got: ', 'Amtel')
# In dataset: False
# Step:340000 - Loss: 1.72174322605
# ('Wanted to predict: ', 'Emmah')
# ('Got: ', 'Emiih')
# In dataset: False
# Step:350000 - Loss: 1.7221082449
# ('Wanted to predict: ', 'Aliva')
# ('Got: ', 'Adika')
# In dataset: True
# Step:360000 - Loss: 1.72243380547
# ('Wanted to predict: ', 'Jyden')
# ('Got: ', 'Jaren')
# In dataset: True
# Step:370000 - Loss: 1.72277092934
# ('Wanted to predict: ', 'Rubee')
# ('Got: ', 'Risin')
# In dataset: False
# Step:380000 - Loss: 1.72313165665
# ('Wanted to predict: ', 'Kalan')
# ('Got: ', 'Kamen')
# In dataset: True
# Step:0 - Loss: 1.7232272625
# ('Wanted to predict: ', 'Alice')
# ('Got: ', 'Ameae')
# In dataset: False
# Step:10000 - Loss: 1.72364985943
# ('Wanted to predict: ', 'Fritz')
# ('Got: ', 'Fratz')
# In dataset: False
# Step:20000 - Loss: 1.72302901745
# ('Wanted to predict: ', 'Lexie')
# ('Got: ', 'Looie')
# In dataset: False
# Step:30000 - Loss: 1.72231185436
# ('Wanted to predict: ', 'Alter')
# ('Got: ', 'Alvon')
# In dataset: True
# Step:40000 - Loss: 1.72190606594
# ('Wanted to predict: ', 'Claud')
# ('Got: ', 'Caerd')
# In dataset: False
# Step:50000 - Loss: 1.72168648243
# ('Wanted to predict: ', 'Benno')
# ('Got: ', 'Brrny')
# In dataset: False
# Step:60000 - Loss: 1.7214359045
# ('Wanted to predict: ', 'Dawne')
# ('Got: ', 'Darna')
# In dataset: False
# Step:70000 - Loss: 1.72112774849
# ('Wanted to predict: ', 'Norva')
# ('Got: ', 'Nelma')
# In dataset: True
# Step:80000 - Loss: 1.72071707249
# ('Wanted to predict: ', 'Toula')
# ('Got: ', 'Trmla')
# In dataset: False
# Step:90000 - Loss: 1.72026741505
# ('Wanted to predict: ', 'Enoch')
# ('Got: ', 'Elnlh')
# In dataset: False
# Step:100000 - Loss: 1.71979415417
# ('Wanted to predict: ', 'Ariel')
# ('Got: ', 'Allel')
# In dataset: False
# Step:110000 - Loss: 1.71935236454
# ('Wanted to predict: ', 'Linzy')
# ('Got: ', 'Londy')
# In dataset: False
# Step:120000 - Loss: 1.71897518635
# ('Wanted to predict: ', 'Devan')
# ('Got: ', 'Donon')
# In dataset: False
# Step:130000 - Loss: 1.71863806248
# ('Wanted to predict: ', 'Sarah')
# ('Got: ', 'Shnah')
# In dataset: False
# Step:140000 - Loss: 1.71834087372
# ('Wanted to predict: ', 'Jacob')
# ('Got: ', 'Jamkb')
# In dataset: False
# Step:150000 - Loss: 1.71806371212
# ('Wanted to predict: ', 'Larri')
# ('Got: ', 'Leray')
# In dataset: True
# Step:160000 - Loss: 1.71778869629
# ('Wanted to predict: ', 'Arlie')
# ('Got: ', 'Aldin')
# In dataset: True
# Step:170000 - Loss: 1.71764492989
# ('Wanted to predict: ', 'Johny')
# ('Got: ', 'Jasni')
# In dataset: False
# Step:180000 - Loss: 1.71756064892
# ('Wanted to predict: ', 'Smita')
# ('Got: ', 'Saita')
# In dataset: False
# Step:190000 - Loss: 1.71755754948
# ('Wanted to predict: ', 'Heidy')
# ('Got: ', 'Haidi')
# In dataset: True
# Step:200000 - Loss: 1.71754288673
# ('Wanted to predict: ', 'Torin')
# ('Got: ', 'Tarin')
# In dataset: True
# Step:210000 - Loss: 1.71753752232
# ('Wanted to predict: ', 'Erynn')
# ('Got: ', 'Elina')
# In dataset: True
# Step:220000 - Loss: 1.71752798557
# ('Wanted to predict: ', 'Jovon')
# ('Got: ', 'Jason')
# In dataset: True
# Step:230000 - Loss: 1.71755468845
# ('Wanted to predict: ', 'Dione')
# ('Got: ', 'Daxne')
# In dataset: False
# Step:240000 - Loss: 1.71760225296
# ('Wanted to predict: ', 'Danan')
# ('Got: ', 'Darey')
# In dataset: True
# Step:250000 - Loss: 1.71769928932
# ('Wanted to predict: ', 'Rendy')
# ('Got: ', 'Roney')
# In dataset: True
# Step:260000 - Loss: 1.71780824661
# ('Wanted to predict: ', 'Brayn')
# ('Got: ', 'Bridn')
# In dataset: False
# Step:270000 - Loss: 1.71793293953
# ('Wanted to predict: ', 'Aries')
# ('Got: ', 'Arion')
# In dataset: True
# Step:280000 - Loss: 1.71811509132
# ('Wanted to predict: ', 'Kyona')
# ('Got: ', 'Kelna')
# In dataset: False
# Step:290000 - Loss: 1.71830964088
# ('Wanted to predict: ', 'Eldar')
# ('Got: ', 'Elion')
# In dataset: True
# Step:300000 - Loss: 1.71857428551
# ('Wanted to predict: ', 'Jaron')
# ('Got: ', 'Jaien')
# In dataset: False
# Step:310000 - Loss: 1.71881246567
# ('Wanted to predict: ', 'Ryaan')
# ('Got: ', 'Raltn')
# In dataset: False
# Step:320000 - Loss: 1.7190964222
# ('Wanted to predict: ', 'Casia')
# ('Got: ', 'Calea')
# In dataset: True
# Step:330000 - Loss: 1.71935641766
# ('Wanted to predict: ', 'Axcel')
# ('Got: ', 'Ariel')
# In dataset: True
# Step:340000 - Loss: 1.71966326237
# ('Wanted to predict: ', 'Emmah')
# ('Got: ', 'Emiir')
# In dataset: False
# Step:350000 - Loss: 1.72000443935
# ('Wanted to predict: ', 'Aliva')
# ('Got: ', 'Adisa')
# In dataset: True
# Step:360000 - Loss: 1.72031283379
# ('Wanted to predict: ', 'Jyden')
# ('Got: ', 'Jaren')
# In dataset: True
# Step:370000 - Loss: 1.7206325531
# ('Wanted to predict: ', 'Rubee')
# ('Got: ', 'Ribin')
# In dataset: False
# Step:380000 - Loss: 1.72097396851
# ('Wanted to predict: ', 'Kalan')
# ('Got: ', 'Kamen')
# In dataset: True
# Step:0 - Loss: 1.72106385231
# ('Wanted to predict: ', 'Alice')
# ('Got: ', 'Ameae')
# In dataset: False
# Step:10000 - Loss: 1.72145855427
# ('Wanted to predict: ', 'Fritz')
# ('Got: ', 'Fradz')
# In dataset: False
# Step:20000 - Loss: 1.72086381912
# ('Wanted to predict: ', 'Lexie')
# ('Got: ', 'Looie')
# In dataset: False
# Step:30000 - Loss: 1.72018277645
# ('Wanted to predict: ', 'Alter')
# ('Got: ', 'Alvon')
# In dataset: True
# Step:40000 - Loss: 1.71980047226
# ('Wanted to predict: ', 'Claud')
# ('Got: ', 'Caers')
# In dataset: False
# Step:50000 - Loss: 1.71960008144
# ('Wanted to predict: ', 'Benno')
# ('Got: ', 'Brrny')
# In dataset: False
# Step:60000 - Loss: 1.71936547756
# ('Wanted to predict: ', 'Dawne')
# ('Got: ', 'Darna')
# In dataset: False
# Step:70000 - Loss: 1.71907746792
# ('Wanted to predict: ', 'Norva')
# ('Got: ', 'Nelma')
# In dataset: True
# Step:80000 - Loss: 1.71869695187
# ('Wanted to predict: ', 'Toula')
# ('Got: ', 'Trmna')
# In dataset: False
# Step:90000 - Loss: 1.718272686
# ('Wanted to predict: ', 'Enoch')
# ('Got: ', 'Elnlh')
# In dataset: False
# Step:100000 - Loss: 1.71782743931
# ('Wanted to predict: ', 'Ariel')
# ('Got: ', 'Allel')
# In dataset: False
# Step:110000 - Loss: 1.71740806103
# ('Wanted to predict: ', 'Linzy')
# ('Got: ', 'Lendy')
# In dataset: True
# Step:120000 - Loss: 1.71704649925
# ('Wanted to predict: ', 'Devan')
# ('Got: ', 'Denon')
# In dataset: True
# Step:130000 - Loss: 1.71672642231
# ('Wanted to predict: ', 'Sarah')
# ('Got: ', 'Sanah')
# In dataset: True
# Step:140000 - Loss: 1.71644330025
# ('Wanted to predict: ', 'Jacob')
# ('Got: ', 'Jamkb')
# In dataset: False
# Step:150000 - Loss: 1.71618771553
# ('Wanted to predict: ', 'Larri')
# ('Got: ', 'Laray')
# In dataset: True
# Step:160000 - Loss: 1.71592521667
# ('Wanted to predict: ', 'Arlie')
# ('Got: ', 'Aldis')
# In dataset: True
# Step:170000 - Loss: 1.7157856226
# ('Wanted to predict: ', 'Johny')
# ('Got: ', 'Jasny')
# In dataset: False
# Step:180000 - Loss: 1.71570539474
# ('Wanted to predict: ', 'Smita')
# ('Got: ', 'Saith')
# In dataset: True
# Step:190000 - Loss: 1.71570110321
# ('Wanted to predict: ', 'Heidy')
# ('Got: ', 'Haidi')
# In dataset: True
# Step:200000 - Loss: 1.7156932354
# ('Wanted to predict: ', 'Torin')
# ('Got: ', 'Tarre')
# In dataset: False
# Step:210000 - Loss: 1.71569120884
# ('Wanted to predict: ', 'Erynn')
# ('Got: ', 'Elina')
# In dataset: True
# Step:220000 - Loss: 1.71569025517
# ('Wanted to predict: ', 'Jovon')
# ('Got: ', 'Jaron')
# In dataset: True
# Step:230000 - Loss: 1.71572053432
# ('Wanted to predict: ', 'Dione')
# ('Got: ', 'Daxne')
# In dataset: False
# Step:240000 - Loss: 1.71578133106
# ('Wanted to predict: ', 'Danan')
# ('Got: ', 'Dareh')
# In dataset: False
# Step:250000 - Loss: 1.71587514877
# ('Wanted to predict: ', 'Rendy')
# ('Got: ', 'Roeey')
# In dataset: False
# Step:260000 - Loss: 1.71598184109
# ('Wanted to predict: ', 'Brayn')
# ('Got: ', 'Bridn')
# In dataset: False
# Step:270000 - Loss: 1.71610879898
# ('Wanted to predict: ', 'Aries')
# ('Got: ', 'Arial')
# In dataset: True
# Step:280000 - Loss: 1.71628201008
# ('Wanted to predict: ', 'Kyona')
# ('Got: ', 'Kelna')
# In dataset: False
# Step:290000 - Loss: 1.71646797657
# ('Wanted to predict: ', 'Eldar')
# ('Got: ', 'Eliir')
# In dataset: False
# Step:300000 - Loss: 1.71672677994
# ('Wanted to predict: ', 'Jaron')
# ('Got: ', 'Jaien')
# In dataset: False
# Step:310000 - Loss: 1.71695113182
# ('Wanted to predict: ', 'Ryaan')
# ('Got: ', 'Ralnl')
# In dataset: False
# Step:320000 - Loss: 1.71722269058
# ('Wanted to predict: ', 'Casia')
# ('Got: ', 'Calee')
# In dataset: True
# Step:330000 - Loss: 1.71746730804
# ('Wanted to predict: ', 'Axcel')
# ('Got: ', 'Asiil')
# In dataset: False
# Step:340000 - Loss: 1.71776521206
# ('Wanted to predict: ', 'Emmah')
# ('Got: ', 'Emiih')
# In dataset: False
# Step:350000 - Loss: 1.71809208393
# ('Wanted to predict: ', 'Aliva')
# ('Got: ', 'Adika')
# In dataset: True
# Step:360000 - Loss: 1.71838510036
# ('Wanted to predict: ', 'Jyden')
# ('Got: ', 'Jaren')
# In dataset: True
# Step:370000 - Loss: 1.71869635582
# ('Wanted to predict: ', 'Rubee')
# ('Got: ', 'Ratin')
# In dataset: False
# Step:380000 - Loss: 1.71901905537
# ('Wanted to predict: ', 'Kalan')
# ('Got: ', 'Kamen')
# In dataset: True
# Step:0 - Loss: 1.71910440922
# ('Wanted to predict: ', 'Alice')
# ('Got: ', 'Ameye')
# In dataset: False
# Step:10000 - Loss: 1.71948850155
# ('Wanted to predict: ', 'Fritz')
# ('Got: ', 'Fratz')
# In dataset: False
# Step:20000 - Loss: 1.71893978119
# ('Wanted to predict: ', 'Lexie')
# ('Got: ', 'Looie')
# In dataset: False
# Step:30000 - Loss: 1.71829926968
# ('Wanted to predict: ', 'Alter')
# ('Got: ', 'Alvon')
# In dataset: True
# Step:40000 - Loss: 1.71793651581
# ('Wanted to predict: ', 'Claud')
# ('Got: ', 'Caerd')
# In dataset: False
# Step:50000 - Loss: 1.7177413702
# ('Wanted to predict: ', 'Benno')
# ('Got: ', 'Berny')
# In dataset: True
# Step:60000 - Loss: 1.71752023697
# ('Wanted to predict: ', 'Dawne')
# ('Got: ', 'Derna')
# In dataset: True
# Step:70000 - Loss: 1.71725308895
# ('Wanted to predict: ', 'Norva')
# ('Got: ', 'Nelma')
# In dataset: True
# Step:80000 - Loss: 1.71689236164
# ('Wanted to predict: ', 'Toula')
# ('Got: ', 'Trnna')
# In dataset: False
# Step:90000 - Loss: 1.71649193764
# ('Wanted to predict: ', 'Enoch')
# ('Got: ', 'Elnlh')
# In dataset: False
# Step:100000 - Loss: 1.71606945992
# ('Wanted to predict: ', 'Ariel')
# ('Got: ', 'Arlel')
# In dataset: False
# Step:110000 - Loss: 1.71567595005
# ('Wanted to predict: ', 'Linzy')
# ('Got: ', 'Londy')
# In dataset: False
# Step:120000 - Loss: 1.71533966064
# ('Wanted to predict: ', 'Devan')
# ('Got: ', 'Denon')
# In dataset: True
# Step:130000 - Loss: 1.71503984928
# ('Wanted to predict: ', 'Sarah')
# ('Got: ', 'Sanah')
# In dataset: True
# Step:140000 - Loss: 1.71477341652
# ('Wanted to predict: ', 'Jacob')
# ('Got: ', 'Jamob')
# In dataset: False
# Step:150000 - Loss: 1.71453094482
# ('Wanted to predict: ', 'Larri')
# ('Got: ', 'Lerry')
# In dataset: True
# Step:160000 - Loss: 1.71428728104
# ('Wanted to predict: ', 'Arlie')
# ('Got: ', 'Alten')
# In dataset: True
# Step:170000 - Loss: 1.71415805817
# ('Wanted to predict: ', 'Johny')
# ('Got: ', 'Jasny')
# In dataset: False
# Step:180000 - Loss: 1.71408247948
# ('Wanted to predict: ', 'Smita')
# ('Got: ', 'Saijh')
# In dataset: False
# Step:190000 - Loss: 1.71407628059
# ('Wanted to predict: ', 'Heidy')
# ('Got: ', 'Haini')
# In dataset: False
# Step:200000 - Loss: 1.71405935287
# ('Wanted to predict: ', 'Torin')
# ('Got: ', 'Tarie')
# In dataset: True
# Step:210000 - Loss: 1.71405172348
# ('Wanted to predict: ', 'Erynn')
# ('Got: ', 'Elica')
# In dataset: True
# Step:220000 - Loss: 1.7140443325
# ('Wanted to predict: ', 'Jovon')
# ('Got: ', 'Jaron')
# In dataset: True
# Step:230000 - Loss: 1.7140712738
# ('Wanted to predict: ', 'Dione')
# ('Got: ', 'Daxne')
# In dataset: False
# Step:240000 - Loss: 1.71411848068
# ('Wanted to predict: ', 'Danan')
# ('Got: ', 'Dareh')
# In dataset: False
# Step:250000 - Loss: 1.71420609951
# ('Wanted to predict: ', 'Rendy')
# ('Got: ', 'Roney')
# In dataset: True
# Step:260000 - Loss: 1.71430814266
# ('Wanted to predict: ', 'Brayn')
# ('Got: ', 'Bridn')
# In dataset: False
# Step:270000 - Loss: 1.71442985535
# ('Wanted to predict: ', 'Aries')
# ('Got: ', 'Arian')
# In dataset: True
# Step:280000 - Loss: 1.71459710598
# ('Wanted to predict: ', 'Kyona')
# ('Got: ', 'Kelna')
# In dataset: False
# Step:290000 - Loss: 1.71477735043
# ('Wanted to predict: ', 'Eldar')
# ('Got: ', 'Elion')
# In dataset: True
# Step:300000 - Loss: 1.71502029896
# ('Wanted to predict: ', 'Jaron')
# ('Got: ', 'Jaien')
# In dataset: False
# Step:310000 - Loss: 1.71524047852
# ('Wanted to predict: ', 'Ryaan')
# ('Got: ', 'Ralnn')
# In dataset: False
# Step:320000 - Loss: 1.71549987793
# ('Wanted to predict: ', 'Casia')
# ('Got: ', 'Calsa')
# In dataset: False
# Step:330000 - Loss: 1.7157355547
# ('Wanted to predict: ', 'Axcel')
# ('Got: ', 'Arier')
# In dataset: False
# Step:340000 - Loss: 1.71601629257
# ('Wanted to predict: ', 'Emmah')
# ('Got: ', 'Emiih')
# In dataset: False
# Step:350000 - Loss: 1.71632862091
# ('Wanted to predict: ', 'Aliva')
# ('Got: ', 'Adisa')
# In dataset: True
# Step:360000 - Loss: 1.716614604
# ('Wanted to predict: ', 'Jyden')
# ('Got: ', 'Jaran')
# In dataset: True
# Step:370000 - Loss: 1.71691334248
# ('Wanted to predict: ', 'Rubee')
# ('Got: ', 'Rotin')
# In dataset: False
# Step:380000 - Loss: 1.71722459793
# ('Wanted to predict: ', 'Kalan')
# ('Got: ', 'Kamen')
# In dataset: True

# %%
# Generate names of length 5! DOES NOT WORK CURRENTLY
import string

def softmax(distribution):
    s = np.sum(np.e**distribution)
    return [(np.e**i)/s for i in distribution]

def get_next_letter(params, letter):
    """
    Takes in all the necessary weights and an OHE letter.
    Returns output distribution and updated internal state
    """
    [whh, wxh, why, Bh, By, h_state] = params
    
    h_state = np.tanh(np.dot(letter, wxh) + np.dot(h_state, whh) + Bh)
    
    # update the output, only the last thing will predict something
    out = np.dot(h_state, why) + By
    
    return softmax(out), h_state

def generate_random_name():
    capitals = list(string.ascii_uppercase)
    
    start_letter = np.random.choice(capitals, 1)[0]
    starting_vec = word2mat(start_letter)
    
    # get all the trained weights from the graph
    [whh, wxh, why, Bh, By]  = sess.run([Whh, Wxh, Why, bh, by])
    h_state = h_last
    vec = starting_vec
    name = start_letter
    for _ in range(4):
        vec, h_state = get_next_letter([whh, wxh, why, Bh, By, h_state], vec)
        name+=dictionary[np.argmax(vec, 1)[0]]
    return name

# %%
generated_names = [generate_random_name() for _ in range(100)]
prop_in_dataset = np.sum([name in length_five for name in list(set(generated_names))])/len(generated_names) 

print("Proportion in original dataset: {}".format(np.round(prop_in_dataset, 2)))
print("Number of unique names: {}".format(len(list(set(generated_names)))))
# Out:
# Proportion in original dataset: 0.1
# Number of unique names: 26

# %%
list(set(generated_names))
# Out:
# ['Harsm',
#  'Kyran',
#  'Osair',
#  'Amain',
#  'Quyid',
#  'Izaak',
#  'Viddy',
#  'Wyldd',
#  'Bowen',
#  'Tyran',
#  'Uzien',
#  'Lanin',
#  'Parro',
#  'Yasin',
#  'Niras',
#  'Daven',
#  'Colen',
#  'Samar',
#  'Emren',
#  'Romdn',
#  'Gargn',
#  'Makin',
#  'Javin',
#  'Xidgh',
#  'Faiah',
#  'Zaran']

# %% [markdown]
# Cool! Now that we made our first RNN, it is time to come make some more fancy RNNs. Perhaps we can also start using some More complex architectures using preexisting layers from Tensorflow!
